# %% [markdown]
# <a href="https://colab.research.google.com/github/Fkoukpaki/Comparative-Analysis-of-Forecasting-Models-of-Time-Series-Data-An-empirical-test/blob/main/statistical_tests05_06.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Statistical tests**

# %% [markdown]
# ***Friedman Test on the outputs of the models***

# %%
# !pip install scikit_posthocs

# %%
# Importing libraries
from scipy import stats
import scikit_posthocs as sp
import numpy as np
import pandas as pd
import math
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg

# %%
# import the dataset
NHITS = pd.read_csv("/content/drive/MyDrive/df/NHITS.csv",sep=';',index_col=0)

# %%
NHITS
# Out:
#            1         3         5
# 12  0.199602  0.199840  0.155668
# 10  0.105452  0.165899  0.166314
# 5   0.081099  0.081363  0.098060
# 1   0.033866  0.047539  0.040215

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(NHITS, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("NHITS")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
ES = pd.read_csv("/content/drive/MyDrive/df/ES.csv",sep=';',index_col=0)
ES
# Out:
#            1         3         5
# 12  0.494516  0.494516  0.494516
# 10  0.342773  0.342773  0.342773
# 5   0.106098  0.106098  0.106098
# 1   0.073751  0.073751  0.073751

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(ES, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("ES")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
ARIMA = pd.read_csv("/content/drive/MyDrive/df/ARIMA.csv",sep=';',index_col=0)
ARIMA
# Out:
#            1         3         5
# 12  0.255279  0.255279  0.255279
# 10  0.213020  0.213020  0.213020
# 5   0.103134  0.103134  0.103134
# 1   0.068832  0.068832  0.068832

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(ARIMA, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("ARIMA")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
EnetCV = pd.read_csv("/content/drive/MyDrive/df/EnetCV.csv",sep=';',index_col=0)
EnetCV
# Out:
#            1         3         5
# 12  0.249416  0.216866  0.207916
# 10  0.191845  0.179218  0.171765
# 5   0.093613  0.091610  0.080791
# 1   0.060167  0.055567  0.048072

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(EnetCV, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("EnetCV")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
GBR = pd.read_csv("/content/drive/MyDrive/df/GBR.csv",sep=';',index_col=0)
GBR
# Out:
#            1         3         5
# 12  0.213457  0.183609  0.091171
# 10  0.194886  0.159502  0.090663
# 5   0.107231  0.098780  0.094933
# 1   0.050532  0.046053  0.044524

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(GBR, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("GBR")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
KNN = pd.read_csv("/content/drive/MyDrive/df/KNN.csv",sep=';',index_col=0)
KNN
# Out:
#            1         3         5
# 12  0.169261  0.150601  0.137836
# 10  0.159329  0.139709  0.116040
# 5   0.137187  0.138572  0.145978
# 1   0.067046  0.041990  0.049216

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(KNN, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("KNN")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
LassoCV = pd.read_csv("/content/drive/MyDrive/df/LassoCV.csv",sep=';',index_col=0)
LassoCV
# Out:
#            1         3         5
# 12  0.251310  0.215423  0.204398
# 10  0.193572  0.176434  0.184172
# 5   0.093387  0.096914  0.088392
# 1   0.059652  0.055047  0.049717

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(LassoCV, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("LassoCV")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
PLS = pd.read_csv("/content/drive/MyDrive/df/PLS.csv",sep=';',index_col=0)
PLS
# Out:
#            1         3         5
# 12  0.278571  0.212158  0.224746
# 10  0.211507  0.175885  0.177679
# 5   0.098740  0.092175  0.080760
# 1   0.063351  0.055151  0.047024

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(PLS, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("PLS")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
RF = pd.read_csv("/content/drive/MyDrive/df/RF.csv",sep=';',index_col=0)
RF
# Out:
#            1         3         5
# 12  0.234909  0.187154  0.178253
# 10  0.220264  0.171973  0.133001
# 5   0.135616  0.107339  0.129276
# 1   0.073316  0.069944  0.073588

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(RF, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("RF")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
RidgeCV = pd.read_csv("/content/drive/MyDrive/df/RidgeCV.csv",sep=';',index_col=0)
RidgeCV
# Out:
#            1         3         5
# 12  0.249380  0.216451  0.205472
# 10  0.191824  0.173355  0.165823
# 5   0.093602  0.091016  0.080690
# 1   0.060133  0.055524  0.048029

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(RidgeCV, cmap = 'coolwarm', center=0.20,square= True,annot=True,cbar_kws={'label': 'dark blue to red=accuracy from best to worst'})
plt.title("RidgeCV")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
dfH1 = pd.read_csv("/content/drive/MyDrive/df/dfH1.csv",sep=';')
dfH1
# Out:
#     Models  MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# 0    NHITS    0.156594    0.003442    0.019674    0.065315    0.040621
# 1       ES    0.194425    0.003058    0.117710    0.072066    0.113514
# 2    ARIMA    0.171897    0.003822    0.101212    0.075019    0.106993
# 3  RidgeCV    0.159032    0.004494    0.043391    0.044907    0.068682
# 4   EnetCV    0.159468    0.004496    0.043438    0.045005    0.068559
# 5  LassoCV    0.114719    0.003042    0.049728    0.061947    0.053131
# 6       RF    0.176569    0.004841    0.033637    0.089822    0.148572
# 7      KNN    0.139522    0.003711    0.008861    0.058136    0.087547
# 8      GBR    0.114697    0.004914    0.047170    0.047005    0.111232
# 9      PLS    0.148141    0.004448    0.042266    0.044853    0.071968
#
#    MSE_split6  MSE_split7  MSE_split8  MSE_split9  MSE_split10
# 0    0.006299    0.010874    0.036765    0.057716     0.004845
# ...

# %%
NHITS = [0.156594,	0.003442,	0.019674,	0.065315,	0.040621,	0.006299,	0.010874,	0.036765,	0.057716,	0.004845];
ES =	[0.194425,	0.003058,	0.117710,	0.072066,	0.113514,	0.018965,	0.027217,	0.007405,	0.170632,	0.012515];
ARIMA	= [0.171897,	0.003822,	0.101212,	0.075019,	0.106993,	0.019376,	0.019888,	0.010649,	0.163844,	0.015621];
RidgeCV = [0.159032,	0.004494,	0.043391,	0.044907,	0.068682,	0.015950,	0.016753,	0.010609,	0.105158,	0.011312]
EnetCV =	[0.159468,	0.004496,	0.043438,	0.045005,	0.068559,	0.015987,	0.016751,	0.010620,	0.105057,	0.011340]
LassoCV = [0.114719,	0.003042,	0.049728,	0.061947,	0.053131,	0.012064,	0.015483,	0.022071,	0.155202,	0.009778]
RF	= [0.176569,	0.004841,	0.033637,	0.089822,	0.148572,	0.097339,	0.016004,	0.030601,	0.124305,	0.014186]
KNN	= [0.139522,	0.003711,	0.008861,	0.058136,	0.087547,	0.049499,	0.082189,	0.015408,	0.038803,	0.008486]
GBR	= [0.114697,	0.004914,	0.047170,	0.047005,	0.111232,	0.007818,	0.010048,	0.009017,	0.084685,	0.008656]
PLS	= [0.148141,	0.004448,	0.042266,	0.044853,	0.071968,	0.015121,	0.017355,	0.010141,	0.106352,	0.009591]


plt.boxplot(ARIMA, positions = [1], widths = 0.9)
plt.boxplot(ES, positions = [2], widths = 0.9) ;
plt.boxplot(RidgeCV, positions = [3], widths = 0.9) ;
plt.boxplot(LassoCV, positions = [4], widths = 0.9) ;
plt.boxplot(PLS, positions = [5], widths = 0.9) ;
plt.boxplot(EnetCV, positions = [6], widths = 0.9) ;
plt.boxplot(KNN, positions = [7], widths = 0.9) ;
plt.boxplot(RF, positions = [8], widths = 0.9) ;
plt.boxplot(GBR, positions = [9], widths = 0.9) ;
plt.boxplot(NHITS, positions = [10], widths = 0.9) ;
plt.gca().xaxis.set_ticklabels(['ARIMA',"ES","RidgeCV","LassoCV","PLS","EnetCV","KNN","RF","GBR","NHITS"]) ;
plt.xticks(rotation=90)
plt.title("NMSE_10 splits when model forecasts traffic_counts in 15min")
plt.ylabel("NMSE")
plt.axis()
plt.show()

# %%
# import the dataset
dfH5 = pd.read_csv("/content/drive/MyDrive/df/dfH5.csv",sep=';')
dfH5
# Out:
#     Models  MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# 0    NHITS    0.279646    0.018454    0.082628    0.061157    0.223636
# 1       ES    0.141187    0.006774    0.154269    0.060086    0.196657
# 2    ARIMA    0.100164    0.021916    0.105290    0.082930    0.189269
# 3  RidgeCV    0.092177    0.017402    0.083256    0.095954    0.134550
# 4   EnetCV    0.107633    0.015554    0.086339    0.081358    0.108754
# 5  LassoCV    0.081799    0.015654    0.072378    0.119837    0.179944
# 6       RF    0.132139    0.221079    0.152466    0.138930    0.295083
# 7      KNN    0.087132    0.022449    0.074201    0.156076    0.783094
# 8      GBR    0.102590    0.031041    0.055398    0.123841    0.415335
# 9      PLS    0.103686    0.015278    0.087599    0.084204    0.117783
#
#    MSE_split6  MSE_split7  MSE_split8  MSE_split9  MSE_split10
# 0    0.033543    0.075183    0.094244    0.084419     0.027687
# ...

# %%
NHITS = [0.279646,	0.018454,	0.082628,	0.061157,	0.223636,	0.033543,	0.075183,	0.094244,	0.084419,	0.027687];
ES =	[0.141187,	0.006774,	0.154269,	0.060086,	0.196657,	0.044550,	0.010489,	0.163165,	0.221280,	0.062523];
ARIMA	= [0.100164,	0.021916,	0.105290,	0.082930,	0.189269,	0.059916,	0.013600,	0.119647,	0.242325,	0.096280];
RidgeCV = [0.092177,	0.017402,	0.083256,	0.095954,	0.134550,	0.010357,	0.015568,	0.144984,	0.100713,	0.111937]
EnetCV =	[0.107633,	0.015554,	0.086339,	0.081358,	0.108754,	0.009346,	0.014871,	0.157757,	0.104104,	0.122191]
LassoCV = [0.081799,	0.015654,	0.072378,	0.119837,	0.179944,	0.013831,	0.014422,	0.153847,	0.115340,	0.116864]
RF	= [0.132139,	0.221079,	0.152466,	0.138930,	0.295083,	0.128951,	0.038240,	0.029960,	0.102024,	0.053890]
KNN	= [0.087132,	0.022449,	0.074201,	0.156076,	0.783094,	0.170085,	0.009962,	0.058945,	0.048911,	0.048924]
GBR	= [0.102590,	0.031041,	0.055398,	0.123841,	0.415335,	0.034943,	0.011404,	0.056047,	0.101942,	0.016788]
PLS	= [0.103686,	0.015278,	0.087599,	0.084204,	0.117783,	0.009591,	0.014109,	0.156622,	0.099101,	0.119624]


plt.boxplot(ARIMA, positions = [1], widths = 0.9) ;
plt.boxplot(ES, positions = [2], widths = 0.9) ;
plt.boxplot(RidgeCV, positions = [3], widths = 0.9) ;
plt.boxplot(LassoCV, positions = [4], widths = 0.9) ;
plt.boxplot(PLS, positions = [5], widths = 0.9) ;
plt.boxplot(EnetCV, positions = [6], widths = 0.9) ;
plt.boxplot(KNN, positions = [7], widths = 0.9) ;
plt.boxplot(RF, positions = [8], widths = 0.9) ;
plt.boxplot(GBR, positions = [9], widths = 0.9) ;
plt.boxplot(NHITS, positions = [10], widths = 0.9) ;
plt.gca().xaxis.set_ticklabels(["ARIMA","ES","RidgeCV","LassoCV","PLS","EnetCV","KNN","RF","GBR","NHITS"]) ;
plt.xticks(rotation=90)
plt.title("NMSE_10 splits when model forecasts traffic_counts in 75min")
plt.ylabel("NMSE")
plt.axis()
plt.show()

# %%
# import the dataset
dfH10 = pd.read_csv("/content/drive/MyDrive/df/dfH10.csv",sep=';')
dfH10
# Out:
#     Models  MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# 0    NHITS    0.204627    0.068482    0.059774    0.074908    0.548997
# 1       ES    0.135699    0.102702    1.064362    0.089909    0.411092
# 2    ARIMA    0.086481    0.045015    0.155164    0.076420    0.275512
# 3  RidgeCV    0.113951    0.035118    0.172454    0.250103    0.116591
# 4   EnetCV    0.102996    0.034606    0.189287    0.263542    0.115448
# 5  LassoCV    0.101177    0.036555    0.200225    0.302677    0.130675
# 6       RF    0.097328    0.185694    0.200667    0.094411    0.147746
# 7      KNN    0.084714    0.147276    0.088337    0.102539    0.281696
# 8      GBR    0.062497    0.058760    0.070972    0.093891    0.124610
# 9      PLS    0.100739    0.036311    0.201642    0.169818    0.128195
#
#    MSE_split6  MSE_split7  MSE_split8  MSE_split9  MSE_split10
# 0    0.394364    0.037719    0.113223    0.091023     0.070020
# ...

# %%
NHITS = [0.204627,	0.068482,	0.059774,	0.074908,	0.548997,	0.394364,	0.037719,	0.113223,	0.091023,	0.070020];
ES =	[0.135699,	0.102702,	1.064362,	0.089909,	0.411092,	0.502506,	0.059154,	0.274728,	0.346026,	0.441552];
ARIMA	= [0.086481,	0.045015,	0.155164,	0.076420,	0.275512,	0.527096,	0.026498,	0.173137,	0.372265,	0.392614];
RidgeCV = [0.113951,	0.035118,	0.172454,	0.250103,	0.116591,	0.356747,	0.024082,	0.227276,	0.254313,	0.107595]
EnetCV =	[0.102996,	0.034606,	0.189287,	0.263542,	0.115448,	0.343853,	0.024006,	0.276179,	0.252453,	0.115285]
LassoCV = [0.101177,	0.036555,	0.200225,	0.302677,	0.130675,	0.459642,	0.025583,	0.194075,	0.244715,	0.146399]
RF	= [0.097328,	0.185694,	0.200667,	0.094411,	0.147746,	0.220508,	0.053185,	0.126302,	0.149020,	0.055147]
KNN	= [0.084714,	0.147276,	0.088337,	0.102539,	0.281696,	0.210344,	0.030566,	0.079307,	0.072063,	0.063557]
GBR	= [0.062497,	0.058760,	0.070972,	0.093891,	0.124610,	0.169714,	0.016913,	0.064373,	0.088961,	0.155943]
PLS	= [0.100739,	0.036311,	0.201642,	0.169818,	0.128195,	0.460186,	0.022036,	0.272458,	0.253510,	0.131898]


plt.boxplot(ARIMA, positions = [1], widths = 0.9) ;
plt.boxplot(ES, positions = [2], widths = 0.9) ;
plt.boxplot(RidgeCV, positions = [3], widths = 0.9) ;
plt.boxplot(LassoCV, positions = [4], widths = 0.9) ;
plt.boxplot(PLS, positions = [5], widths = 0.9) ;
plt.boxplot(EnetCV, positions = [6], widths = 0.9) ;
plt.boxplot(KNN, positions = [7], widths = 0.9) ;
plt.boxplot(RF, positions = [8], widths = 0.9) ;
plt.boxplot(GBR, positions = [9], widths = 0.9) ;
plt.boxplot(NHITS, positions = [10], widths = 0.9) ;
plt.gca().xaxis.set_ticklabels(["ARIMA","ES","RidgeCV","LassoCV","PLS","EnetCV","KNN","RF","GBR","NHITS"]) ;
plt.xticks(rotation=90)
plt.title("NMSE_10 splits when model forecasts traffic_counts in 150min")
plt.ylabel("NMSE")
plt.axis()
plt.show()

# %%
# import the dataset
dfH12 = pd.read_csv("/content/drive/MyDrive/df/dfH12.csv",sep=';')
dfH12
# Out:
#     Models  MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# 0    NHITS    0.092029    0.101773    0.044919    0.065011    0.398725
# 1       ES    0.146678    0.238402    1.481594    0.156482    0.644883
# 2    ARIMA    0.090153    0.093338    0.136559    0.136485    0.475505
# 3  RidgeCV    0.165824    0.045952    0.215025    0.198749    0.380455
# 4   EnetCV    0.139404    0.044634    0.221461    0.214771    0.450590
# 5  LassoCV    0.143748    0.063754    0.239153    0.170205    0.245040
# 6       RF    0.132092    0.153776    0.238163    0.092042    0.168866
# 7      KNN    0.092729    0.142290    0.077222    0.157632    0.168665
# 8      GBR    0.120131    0.033825    0.074060    0.137039    0.150310
# 9      PLS    0.138844    0.046179    0.225140    0.205176    0.381536
#
#    MSE_split6  MSE_split7  MSE_split8  MSE_split9  MSE_split10
# 0    0.249971    0.046654    0.153524    0.102509     0.301570
# ...

# %%
NHITS = [0.092029,	0.101773,	0.044919,	0.065011,	0.398725,	0.249971,	0.046654,	0.153524,	0.102509,	0.301570];
ES =	[0.146678,	0.238402,	1.481594,	0.156482,	0.644883,	0.505251,	0.052306,	0.186988,	0.313310,	1.219264];
ARIMA	= [0.090153,	0.093338,	0.136559,	0.136485,	0.475505,	0.475050,	0.039964,	0.101026,	0.296357,	0.708351];
RidgeCV = [0.165824,	0.045952,	0.215025,	0.198749,	0.380455,	0.249360,	0.106651,	0.087028,	0.233627,	0.372044]
EnetCV =	[0.139404,	0.044634,	0.221461,	0.214771,	0.450590,	0.217190,	0.108115,	0.091292,	0.220245,	0.371459]
LassoCV = [0.143748,	0.063754,	0.239153,	0.170205,	0.245040,	0.385403,	0.112559,	0.100504,	0.234106,	0.349514]
RF	= [0.132092,	0.153776,	0.238163,	0.092042,	0.168866,	0.204288,	0.079728,	0.217783,	0.120910,	0.374880]
KNN	= [0.092729,	0.142290,	0.077222,	0.157632,	0.168665,	0.222357,	0.029548,	0.125132,	0.118797,	0.243990]
GBR	= [0.120131,	0.033825,	0.074060,	0.137039,	0.150310,	0.092397,	0.011498,	0.051276,	0.107024,	0.134155]
PLS	= [0.138844,	0.046179,	0.225140,	0.205176,	0.381536,	0.474357,	0.089835,	0.083153,	0.315752,	0.287492]


plt.boxplot(ARIMA, positions = [1], widths = 0.9) ;
plt.boxplot(ES, positions = [2], widths = 0.9) ;
plt.boxplot(RidgeCV, positions = [3], widths = 0.9) ;
plt.boxplot(LassoCV, positions = [4], widths = 0.9) ;
plt.boxplot(PLS, positions = [5], widths = 0.9) ;
plt.boxplot(EnetCV, positions = [6], widths = 0.9) ;
plt.boxplot(KNN, positions = [7], widths = 0.9) ;
plt.boxplot(RF, positions = [8], widths = 0.9) ;
plt.boxplot(GBR, positions = [9], widths = 0.9) ;
plt.boxplot(NHITS, positions = [10], widths = 0.9) ;
plt.gca().xaxis.set_ticklabels(["ARIMA","ES","RidgeCV","LassoCV","PLS","EnetCV","KNN","RF","GBR","NHITS"]) ;
plt.xticks(rotation=90)
plt.title("NMSE_10 splits when model forecasts traffic_counts in 180min")
plt.ylabel("NMSE")
plt.axis()
plt.show()

# %%
# Setting of the desired alpha/significance level
alpha = 0.05

# %% [markdown]
# **---H = 1**: MSEs obtained by using the 5 most recent historical

# %%
# import the dataset
dfH1 = pd.read_csv("/content/drive/MyDrive/df/dfH1.csv",sep=';',index_col=0)
df1= dfH1
df1
df_1= dfH1.T
df_1
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.156594  0.194425  0.171897  0.159032  0.159468  0.114719
# MSE_split2   0.003442  0.003058  0.003822  0.004494  0.004496  0.003042
# MSE_split3   0.019674  0.117710  0.101212  0.043391  0.043438  0.049728
# MSE_split4   0.065315  0.072066  0.075019  0.044907  0.045005  0.061947
# MSE_split5   0.040621  0.113514  0.106993  0.068682  0.068559  0.053131
# MSE_split6   0.006299  0.018965  0.019376  0.015950  0.015987  0.012064
# MSE_split7   0.010874  0.027217  0.019888  0.016753  0.016751  0.015483
# MSE_split8   0.036765  0.007405  0.010649  0.010609  0.010620  0.022071
# MSE_split9   0.057716  0.170632  0.163844  0.105158  0.105057  0.155202
# MSE_split10  0.004845  0.012515  0.015621  0.011312  0.011340  0.009778
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.176569  0.139522  0.114697  0.148141
# MSE_split2   0.004841  0.003711  0.004914  0.004448
# ...

# %%
dfH1
# Out:
#          MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# Models
# NHITS      0.156594    0.003442    0.019674    0.065315    0.040621
# ES         0.194425    0.003058    0.117710    0.072066    0.113514
# ARIMA      0.171897    0.003822    0.101212    0.075019    0.106993
# RidgeCV    0.159032    0.004494    0.043391    0.044907    0.068682
# EnetCV     0.159468    0.004496    0.043438    0.045005    0.068559
# LassoCV    0.114719    0.003042    0.049728    0.061947    0.053131
# RF         0.176569    0.004841    0.033637    0.089822    0.148572
# KNN        0.139522    0.003711    0.008861    0.058136    0.087547
# GBR        0.114697    0.004914    0.047170    0.047005    0.111232
# PLS        0.148141    0.004448    0.042266    0.044853    0.071968
#
#          MSE_split6  MSE_split7  MSE_split8  MSE_split9  MSE_split10
# Models
# NHITS      0.006299    0.010874    0.036765    0.057716     0.004845
# ...

# %%
#transforming the data

NMSE_H1 = np.array(df_1)
NMSE_H1.shape
data_1 = np.asarray(NMSE_H1)
num_datasets1, num_methods1 = data_1.shape
print("Methods:", num_methods1, "Datasets:", num_datasets1)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
# statistic of friedman
stat, p= stats.friedmanchisquare(*data_1)
#printing the result
print(stat, p)
# decision rule
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
# Out:
# 78.67636363636365 2.95939522210765e-13
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True

# %% [markdown]
# Here, the Friedman test statistic is 78.68 and the corresponding p-value is 2.96e-13. As this p-value is less than 0.05, we can reject the null hypothesis which states that the NMSEs of the models used are equal whatever the splits. In other words, we have sufficient evidence to conclude that among the models used there are at least two whose NMSEs are significantly different. Thus, we performed the Nemenyi test to assess the performance of the models pairwise.

# %% [markdown]
# **2- identify the methods that differ significantly using the Nemenyi test**

# %%
dfH1
# Out:
#          MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# Models
# NHITS      0.197466    0.001938    0.029490    0.088680    0.030232
# ES         0.194425    0.003058    0.117710    0.072066    0.113514
# ARIMA      0.171897    0.003822    0.101212    0.075019    0.106993
# RidgeCV    0.142377    0.004258    0.054039    0.051025    0.138963
# EnetCV     0.142652    0.004261    0.054129    0.051122    0.138948
# LassoCV    0.112095    0.002241    0.070042    0.057165    0.138113
# RF         0.152380    0.005830    0.044628    0.089394    0.134044
# KNN        0.123836    0.003851    0.056352    0.037581    0.153760
# GBR        0.094186    0.003832    0.028577    0.034520    0.110402
# PLS        0.142652    0.004261    0.054129    0.051122    0.138948
#
#          MSE_split6  MSE_split7  MSE_split8  MSE_split9  MSE_split10
# Models
# NHITS      0.008787    0.008701    0.083577    0.095962     0.002361
# ...

# %%
# average rank of the methods
# tranforming data
df1['Rank_MSE_split1'] = df1.MSE_split1.rank(ascending = True)
df1['Rank_MSE_split2']=df1.MSE_split2.rank(ascending = True)
df1['Rank_MSE_split3']=df1.MSE_split3.rank(ascending = True)
df1['Rank_MSE_split4'] = df1.MSE_split4.rank(ascending = True)
df1['Rank_MSE_split5']=df1.MSE_split5.rank(ascending = True)
df1['Rank_MSE_split6']=df1.MSE_split6.rank(ascending = True)
df1['Rank_MSE_split7'] = df1.MSE_split7.rank(ascending = True)
df1['Rank_MSE_split8']=df1.MSE_split8.rank(ascending = True)
df1['Rank_MSE_split9']=df1.MSE_split9.rank(ascending = True)
df1['Rank_MSE_split10'] = df1.MSE_split10.rank(ascending = True)
df1.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df1['mean']= df1.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df1['mean']
# Out:
# Models
# NHITS      3.4
# ES         7.4
# ARIMA      7.9
# RidgeCV    5.0
# EnetCV     5.4
# LassoCV    4.6
# RF         8.0
# KNN        4.8
# GBR        4.1
# PLS        4.4
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA','RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df1 = [3.4,7.4,7.9,5.0,5.4,4.6,8.0,4.8,4.1,4.4]

# %%
# defining the critical difference function

def compute_CD(avranks, n, alpha=0.1, test="nemenyi"):
    """
    Returns critical difference for Nemenyi or Bonferroni-Dunn test
    according to given alpha (either alpha="0.05" or alpha="0.1") for average
    ranks and number of tested datasets N. Test can be either "nemenyi" for
    for Nemenyi two tailed test or "bonferroni-dunn" for Bonferroni-Dunn test.
    Args:
	avranks (int or list): list of average ranks or the number of methods
	n (int): number of data sets
	alpha (float): alpha level; must be either 0.05 or 0.1
	test (str): "nemenyi" or "bonferroni-dunn"
    """
    k = avranks if isinstance(avranks, int) else len(avranks)
    d = {("nemenyi", 0.05): [0, 0, 1.959964, 2.343701, 2.569032, 2.727774,
                               2.849705, 2.94832, 3.030879, 3.101730, 3.163684,
                               3.218654, 3.268004, 3.312739, 3.353618, 3.39123,
                               3.426041, 3.458425, 3.488685, 3.517073,
                               3.543799],
         ("nemenyi", 0.1): [0, 0, 1.644854, 2.052293, 2.291341, 2.459516,
                              2.588521, 2.692732, 2.779884, 2.854606, 2.919889,
                              2.977768, 3.029694, 3.076733, 3.119693, 3.159199,
                              3.195743, 3.229723, 3.261461, 3.291224, 3.319233],
         ("bonferroni-dunn", 0.05): [0, 0, 1.960, 2.241, 2.394, 2.498, 2.576,
                                       2.638, 2.690, 2.724, 2.773],
         ("bonferroni-dunn", 0.1): [0, 0, 1.645, 1.960, 2.128, 2.241, 2.326,
                                      2.394, 2.450, 2.498, 2.539]}
    q = d[(test, alpha)]
    cd = q[k] * (k * (k + 1) / (6.0 * n)) ** 0.5
    return cd

# %%
# computing the critical difference

cd_df1=compute_CD(avranks_df1, 10, alpha=0.05, test="nemenyi")
cd_df1
# Out:
# 4.283648386022052

# %%
# defining the function to visualise the difference graph

def graph_ranks(avranks, names, cd=None, cdmethod=None, lowv=None, highv=None,
                width=6, textspace=1, reverse=False, filename=None, **kwargs):
    """
    Draws a CD graph, which is used to display  the differences in methods'
    performance. See Janez Demsar, Statistical Comparisons of Classifiers over
    Multiple Data Sets, 7(Jan):1--30, 2006.
    Needs matplotlib to work.
    The image is ploted on `plt` imported using `import matplotlib.pyplot as plt`.
    Args:
        avranks (list of float): average ranks of methods.
        names (list of str): names of methods.
        cd (float): Critical difference used for statistically significance of
            difference between methods.
        cdmethod (int, optional): the method that is compared with other methods
            If omitted, show pairwise comparison of methods
        lowv (int, optional): the lowest shown rank
        highv (int, optional): the highest shown rank
        width (int, optional): default width in inches (default: 6)
        textspace (int, optional): space on figure sides (in inches) for the
            method names (default: 1)
        reverse (bool, optional):  if set to `True`, the lowest rank is on the
            right (default: `False`)
        filename (str, optional): output file name (with extension). If not
            given, the function does not write a file.
    """
    width = float(width)
    textspace = float(textspace)

    def nth(l, n):
        """
        Returns only nth elemnt in a list.
        """
        n = lloc(l, n)
        return [a[n] for a in l]

    def lloc(l, n):
        """
        List location in list of list structure.
        Enable the use of negative locations:
        -1 is the last element, -2 second last...
        """
        if n < 0:
            return len(l[0]) + n
        else:
            return n

    def mxrange(lr):
        """
        Multiple xranges. Can be used to traverse matrices.
        This function is very slow due to unknown number of
        parameters.
        >>> mxrange([3,5])
        [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)]
        >>> mxrange([[3,5,1],[9,0,-3]])
        [(3, 9), (3, 6), (3, 3), (4, 9), (4, 6), (4, 3)]
        """
        if not len(lr):
            yield ()
        else:
            # it can work with single numbers
            index = lr[0]
            if isinstance(index, int):
                index = [index]
            for a in range(*index):
                for b in mxrange(lr[1:]):
                    yield tuple([a] + list(b))

    def print_figure(fig, *args, **kwargs):
        canvas = FigureCanvasAgg(fig)
        canvas.print_figure(*args, **kwargs)

    sums = avranks

    tempsort = sorted([(a, i) for i, a in enumerate(sums)], reverse=reverse)
    ssums = nth(tempsort, 0)
    sortidx = nth(tempsort, 1)
    nnames = [names[x] for x in sortidx]

    if lowv is None:
        lowv = min(1, int(math.floor(min(ssums))))
    if highv is None:
        highv = max(len(avranks), int(math.ceil(max(ssums))))

    cline = 0.4

    k = len(sums)

    lines = None

    linesblank = 0
    scalewidth = width - 2 * textspace

    def rankpos(rank):
        if not reverse:
            a = rank - lowv
        else:
            a = highv - rank
        return textspace + scalewidth / (highv - lowv) * a

    distanceh = 0.25

    if cd and cdmethod is None:
        # get pairs of non significant methods

        def get_lines(sums, hsd):
            # get all pairs
            lsums = len(sums)
            allpairs = [(i, j) for i, j in mxrange([[lsums], [lsums]]) if j > i]
            # remove not significant
            notSig = [(i, j) for i, j in allpairs
                      if abs(sums[i] - sums[j]) <= hsd]
            # keep only longest

            def no_longer(ij_tuple, notSig):
                i, j = ij_tuple
                for i1, j1 in notSig:
                    if (i1 <= i and j1 > j) or (i1 < i and j1 >= j):
                        return False
                return True

            longest = [(i, j) for i, j in notSig if no_longer((i, j), notSig)]

            return longest

        lines = get_lines(ssums, cd)
        linesblank = 0.2 + 0.2 + (len(lines) - 1) * 0.1

        # add scale
        distanceh = 0.25
        cline += distanceh

    # calculate height needed height of an image
    minnotsignificant = max(2 * 0.2, linesblank)
    height = cline + ((k + 1) / 2) * 0.2 + minnotsignificant

    fig = plt.figure(figsize=(width, height))
    fig.set_facecolor('white')
    ax = fig.add_axes([0, 0, 1, 1])  # reverse y axis
    ax.set_axis_off()

    hf = 1. / height  # height factor
    wf = 1. / width

    def hfl(l):
        return [a * hf for a in l]

    def wfl(l):
        return [a * wf for a in l]


    # Upper left corner is (0,0).
    ax.plot([0, 1], [0, 1], c="w")
    ax.set_xlim(0, 1)
    ax.set_ylim(1, 0)

    def line(l, color='k', **kwargs):
        """
        Input is a list of pairs of points.
        """
        ax.plot(wfl(nth(l, 0)), hfl(nth(l, 1)), color=color, **kwargs)

    def text(x, y, s, *args, **kwargs):
        ax.text(wf * x, hf * y, s, *args, **kwargs)

    line([(textspace, cline), (width - textspace, cline)], linewidth=0.7)

    bigtick = 0.1
    smalltick = 0.05

    tick = None
    for a in list(np.arange(lowv, highv, 0.5)) + [highv]:
        tick = smalltick
        if a == int(a):
            tick = bigtick
        line([(rankpos(a), cline - tick / 2),
              (rankpos(a), cline)],
             linewidth=0.7)

    for a in range(lowv, highv + 1):
        text(rankpos(a), cline - tick / 2 - 0.05, str(a),
             ha="center", va="bottom")

    k = len(ssums)

    for i in range(math.ceil(k / 2)):
        chei = cline + minnotsignificant + i * 0.2
        line([(rankpos(ssums[i]), cline),
              (rankpos(ssums[i]), chei),
              (textspace - 0.1, chei)],
             linewidth=0.7)
        text(textspace - 0.2, chei, nnames[i], ha="right", va="center")

    for i in range(math.ceil(k / 2), k):
        chei = cline + minnotsignificant + (k - i - 1) * 0.2
        line([(rankpos(ssums[i]), cline),
              (rankpos(ssums[i]), chei),
              (textspace + scalewidth + 0.1, chei)],
             linewidth=0.7)
        text(textspace + scalewidth + 0.2, chei, nnames[i],
             ha="left", va="center")

    if cd and cdmethod is None:
        # upper scale
        if not reverse:
            begin, end = rankpos(lowv), rankpos(lowv + cd)
        else:
            begin, end = rankpos(highv), rankpos(highv - cd)

        line([(begin, distanceh), (end, distanceh)], linewidth=0.7)
        line([(begin, distanceh + bigtick / 2),
              (begin, distanceh - bigtick / 2)],
             linewidth=0.7)
        line([(end, distanceh + bigtick / 2),
              (end, distanceh - bigtick / 2)],
             linewidth=0.7)
        text((begin + end) / 2, distanceh - 0.05, "CD",
             ha="center", va="bottom")

        # no-significance lines
        def draw_lines(lines, side=0.05, height=0.1):
            start = cline + 0.2
            for l, r in lines:
                line([(rankpos(ssums[l]) - side, start),
                      (rankpos(ssums[r]) + side, start)],
                     linewidth=2.5)
                start += height

        draw_lines(lines)

    elif cd:
        begin = rankpos(avranks[cdmethod] - cd)
        end = rankpos(avranks[cdmethod] + cd)
        line([(begin, cline), (end, cline)],
             linewidth=2.5)
        line([(begin, cline + bigtick / 2),
              (begin, cline - bigtick / 2)],
             linewidth=2.5)
        line([(end, cline + bigtick / 2),
              (end, cline - bigtick / 2)],
             linewidth=2.5)

    if filename:
        print_figure(fig, filename, **kwargs)

# %%
# plot the graph
graph_ranks(avranks_df1, names, cd=cd_df1,width=6, textspace=1)

# %% [markdown]
# bonferroni

# %%
cd_df1=compute_CD(avranks_df1, 10, alpha=0.05, test="bonferroni-dunn")
cd_df1
# Out:
# 3.7546597493425864

# %%
# plot the graph
graph_ranks(avranks_df1, names, cd=cd_df1,width=6, textspace=1,cdmethod=1)

# %%
# plot the graph
graph_ranks(avranks_df1, names, cd=cd_df1,width=6, textspace=1,cdmethod=2)

# %% [markdown]
# **H = 5:** **NMSEs obtained by using the 5 most recent historical observations**

# %%
#importing the data
dfH5=pd.read_csv("/content/drive/MyDrive/df/dfH5.csv",sep=';',index_col=0)
df2= dfH5
df_2= dfH5.T
df_2
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.279646  0.141187  0.100164  0.092177  0.107633  0.081799
# MSE_split2   0.018454  0.006774  0.021916  0.017402  0.015554  0.015654
# MSE_split3   0.082628  0.154269  0.105290  0.083256  0.086339  0.072378
# MSE_split4   0.061157  0.060086  0.082930  0.095954  0.081358  0.119837
# MSE_split5   0.223636  0.196657  0.189269  0.134550  0.108754  0.179944
# MSE_split6   0.033543  0.044550  0.059916  0.010357  0.009346  0.013831
# MSE_split7   0.075183  0.010489  0.013600  0.015568  0.014871  0.014422
# MSE_split8   0.094244  0.163165  0.119647  0.144984  0.157757  0.153847
# MSE_split9   0.084419  0.221280  0.242325  0.100713  0.104104  0.115340
# MSE_split10  0.027687  0.062523  0.096280  0.111937  0.122191  0.116864
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.132139  0.087132  0.102590  0.103686
# MSE_split2   0.221079  0.022449  0.031041  0.015278
# ...

# %%
# transforming the data
NMSE_H5 = np.array(df_2)
data_2 = np.asarray(NMSE_H5)
num_datasets2, num_methods2 = data_2.shape
print("Methods:", num_methods2, "Datasets:", num_datasets2)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
#statistic of Friedman and decision rule
stat, p = stats.friedmanchisquare(*data_2)
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
print(stat, p)
# Out:
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True
# 48.80727272727273 1.803759508281044e-07

# %% [markdown]
# La statistique du test de Friedman est égale à 48.81 et la p-value correspondante est égale à 1.80e-07. Cette p-value étant inférieure à 0.05, on rejette l'hypothèse nulle qui stipule que les MSEs des prévisions faites par les modèles utilisés sont égaux quel que soit le nombre de splits.En d'autres termes, nous avons suffisamment de preuves pour affirmer qu'il y a au moins deux modèles utilisés qui sont significativement différents au seuil de 5%.

# %%
df_2

# %%
# average rank of the methods
# tranforming data
df2['Rank_MSE_split1'] = df2.MSE_split1.rank(ascending = True)
df2['Rank_MSE_split2']=df2.MSE_split2.rank(ascending = True)
df2['Rank_MSE_split3']=df2.MSE_split3.rank(ascending = True)
df2['Rank_MSE_split4'] = df2.MSE_split4.rank(ascending = True)
df2['Rank_MSE_split5']=df2.MSE_split5.rank(ascending = True)
df2['Rank_MSE_split6']=df2.MSE_split6.rank(ascending = True)
df2['Rank_MSE_split7'] = df2.MSE_split7.rank(ascending = True)
df2['Rank_MSE_split8']=df2.MSE_split8.rank(ascending = True)
df2['Rank_MSE_split9']=df2.MSE_split9.rank(ascending = True)
df2['Rank_MSE_split10'] = df2.MSE_split10.rank(ascending = True)
df2.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df2['mean']= df2.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df2['mean']
# Out:
# Models
# NHITS      5.2
# ES         6.0
# ARIMA      6.1
# RidgeCV    5.0
# EnetCV     5.4
# LassoCV    5.1
# RF         7.3
# KNN        5.1
# GBR        4.9
# PLS        4.9
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA', 'RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df2 = [5.2,6.0,6.1,5.0,5.4,5.1,7.3,5.1,4.9,4.9]

# %%
# computing the critical difference

cd_df2=compute_CD(avranks_df2, 10, alpha=0.05, test="nemenyi")
cd_df2
# Out:
# 4.283648386022052

# %%
# plot the graph
graph_ranks(avranks_df2, names, cd=cd_df2,width=6, textspace=1)

# %% [markdown]
# Bonferroni

# %%
cd_df2=compute_CD(avranks_df2, 10, alpha=0.05, test="bonferroni-dunn")
cd_df2
# Out:
# 3.7546597493425864

# %%
# plot the graph
graph_ranks(avranks_df2, names, cd=cd_df2,width=6, textspace=1,cdmethod=1)

# %%
# plot the graph
graph_ranks(avranks_df2, names, cd=cd_df2,width=6, textspace=1,cdmethod=2)

# %% [markdown]
# H = 10: NMSEs obtained by using the 5 most recent historical observations

# %%
#reading the data
dfH10= pd.read_csv("/content/drive/MyDrive/df/dfH10.csv",sep=';',index_col=0)
df3= dfH10
df_3= dfH10.T
df_3
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.204627  0.135699  0.086481  0.113951  0.102996  0.101177
# MSE_split2   0.068482  0.102702  0.045015  0.035118  0.034606  0.036555
# MSE_split3   0.059774  1.064362  0.155164  0.172454  0.189287  0.200225
# MSE_split4   0.074908  0.089909  0.076420  0.250103  0.263542  0.302677
# MSE_split5   0.548997  0.411092  0.275512  0.116591  0.115448  0.130675
# MSE_split6   0.394364  0.502506  0.527096  0.356747  0.343853  0.459642
# MSE_split7   0.037719  0.059154  0.026498  0.024082  0.024006  0.025583
# MSE_split8   0.113223  0.274728  0.173137  0.227276  0.276179  0.194075
# MSE_split9   0.091023  0.346026  0.372265  0.254313  0.252453  0.244715
# MSE_split10  0.070020  0.441552  0.392614  0.107595  0.115285  0.146399
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.097328  0.084714  0.062497  0.100739
# MSE_split2   0.185694  0.147276  0.058760  0.036311
# ...

# %%
# transforming the data
MSE_H10 = np.array(df_3)
data_3= np.asarray(MSE_H10)
num_datasets3, num_methods3 = data_3.shape
print("Methods:", num_methods3, "Datasets:", num_datasets3)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
# statistic of Friedman and decision rule
stat, p = stats.friedmanchisquare(*data_3)
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
print(stat, p)
# Out:
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True
# 52.952727272727316 2.983849494290995e-08

# %% [markdown]
# La statistique du test de Friedman est égale à 52.95 et la p-value correspondante est égale à 2.98e-08. Cette p-value étant inférieure à 0.05, nous avons rejeté l'hypothèse nulle qui stipule que les MSEs des prévisions faites par les modèles utilisés sont égaux quel que soit le nombre de splits.En d'autres termes, nous avons suffisamment de preuves pour affirmer qu'il y a parmi les modèles utilisés au moins deux dont les MSEs sont significativement différents au seuil de 5%. Ainsi, nous avons réalisé le test de Nemenyi afin de tester les performances des modèles par paires.

# %% [markdown]
# **2- identify the methods that differ significantly using the Nemenyi test**

# %%
# average rank of the methods
# tranforming data
df3['Rank_MSE_split1'] = df3.MSE_split1.rank(ascending = True)
df3['Rank_MSE_split2']= df3.MSE_split2.rank(ascending = True)
df3['Rank_MSE_split3']= df3.MSE_split3.rank(ascending = True)
df3['Rank_MSE_split4'] = df3.MSE_split4.rank(ascending = True)
df3['Rank_MSE_split5']= df3.MSE_split5.rank(ascending = True)
df3['Rank_MSE_split6']= df3.MSE_split6.rank(ascending = True)
df3['Rank_MSE_split7'] = df3.MSE_split7.rank(ascending = True)
df3['Rank_MSE_split8']= df3.MSE_split8.rank(ascending = True)
df3['Rank_MSE_split9']= df3.MSE_split9.rank(ascending = True)
df3['Rank_MSE_split10'] = df3.MSE_split10.rank(ascending = True)
df3.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df3['mean']= df3.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df3['mean']
# Out:
# Models
# NHITS      5.2
# ES         8.6
# ARIMA      6.1
# RidgeCV    5.3
# EnetCV     5.2
# LassoCV    6.2
# RF         5.4
# KNN        4.2
# GBR        2.9
# PLS        5.9
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA', 'RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df3 = [5.2,8.6,6.1,5.3,5.2,6.2,5.4,4.2,2.9,5.9]

# %%
# computing the critical difference

cd_df3=compute_CD(avranks_df3, 10, alpha=0.05, test="nemenyi")
cd_df3
# Out:
# 4.283648386022052

# %%
# plot the graph
graph_ranks(avranks_df3, names, cd=cd_df3,width=6, textspace=1)

# %% [markdown]
# Bonferroni

# %%
cd_df3=compute_CD(avranks_df3, 10, alpha=0.05, test="bonferroni-dunn")
cd_df3
# Out:
# 3.7546597493425864

# %%
# plot the graph
graph_ranks(avranks_df3, names, cd=cd_df3,width=6, textspace=1,cdmethod=1)

# %%
# plot the graph
graph_ranks(avranks_df3, names, cd=cd_df3,width=6, textspace=1,cdmethod=2)

# %% [markdown]
# **H** = 12: NMSEs obtained by using the 5 most recent historical observations

# %%
#reading the data
dfH12= pd.read_csv("/content/drive/MyDrive/df/dfH12.csv",sep=';',index_col=0)
df4= dfH12
df_4= dfH12.T
df_4
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.092029  0.146678  0.090153  0.165824  0.139404  0.143748
# MSE_split2   0.101773  0.238402  0.093338  0.045952  0.044634  0.063754
# MSE_split3   0.044919  1.481594  0.136559  0.215025  0.221461  0.239153
# MSE_split4   0.065011  0.156482  0.136485  0.198749  0.214771  0.170205
# MSE_split5   0.398725  0.644883  0.475505  0.380455  0.450590  0.245040
# MSE_split6   0.249971  0.505251  0.475050  0.249360  0.217190  0.385403
# MSE_split7   0.046654  0.052306  0.039964  0.106651  0.108115  0.112559
# MSE_split8   0.153524  0.186988  0.101026  0.087028  0.091292  0.100504
# MSE_split9   0.102509  0.313310  0.296357  0.233627  0.220245  0.234106
# MSE_split10  0.301570  1.219264  0.708351  0.372044  0.371459  0.349514
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.132092  0.092729  0.120131  0.138844
# MSE_split2   0.153776  0.142290  0.033825  0.046179
# ...

# %%
# transforming the data
MSE_H12 = np.array(df_4)
data_4= np.asarray(MSE_H12)
num_datasets4, num_methods4 = data_4.shape
print("Methods:", num_methods4, "Datasets:", num_datasets4)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
# statistic of Friedman and decision rule
stat, p = stats.friedmanchisquare(*data_4)
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
print(stat, p)
# Out:
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True
# 58.75636363636369 2.326282468223639e-09

# %% [markdown]
# La statistique du test de Friedman est égale à 58.76 et la p-value correspondante est égale à 2.33e-09 Cette p-value étant inférieure à 0.05, nous allons rejeté l'hypothèse nulle qui stipule que les NMSEs des prévisions faites par les modèles utilisés sont égaux quel que soit le nombre de splits.Ainsi, nous pouvons réalisé le test de Nemenyi afin de tester les performances des modèles par paires.

# %% [markdown]
# **2- identify the methods that differ significantly using the Nemenyi test**

# %%
# average rank of the methods
# tranforming data
df4['Rank_MSE_split1'] = df4.MSE_split1.rank(ascending = True)
df4['Rank_MSE_split2']= df4.MSE_split2.rank(ascending = True)
df4['Rank_MSE_split3']= df4.MSE_split3.rank(ascending = True)
df4['Rank_MSE_split4'] = df4.MSE_split4.rank(ascending = True)
df4['Rank_MSE_split5']= df4.MSE_split5.rank(ascending = True)
df4['Rank_MSE_split6']= df4.MSE_split6.rank(ascending = True)
df4['Rank_MSE_split7'] = df4.MSE_split7.rank(ascending = True)
df4['Rank_MSE_split8']= df4.MSE_split8.rank(ascending = True)
df4['Rank_MSE_split9']= df4.MSE_split9.rank(ascending = True)
df4['Rank_MSE_split10'] = df4.MSE_split10.rank(ascending = True)
df4.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df4['mean']= df4.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df4['mean']
# Out:
# Models
# NHITS      4.1
# ES         8.7
# ARIMA      5.8
# RidgeCV    6.0
# EnetCV     6.0
# LassoCV    6.7
# RF         5.7
# KNN        4.0
# GBR        1.8
# PLS        6.2
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA','RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df4 = [4.1,8.7,5.8,6.0,6.0,6.7,5.7,4.0,1.8,6.2]

# %%
# computing the critical difference

cd_df4=compute_CD(avranks_df4, 10, alpha=0.05, test="nemenyi")
cd_df4
# Out:
# 4.283648386022052

# %%
# plot the graph
graph_ranks(avranks_df4, names, cd=cd_df4,width=6, textspace=1)

# %% [markdown]
# Bonferroni

# %%
cd_df4=compute_CD(avranks_df4, 10, alpha=0.05, test="bonferroni-dunn")
cd_df4
# Out:
# 3.7546597493425864

# %%
# plot the graph
graph_ranks(avranks_df4, names, cd=cd_df4,width=6, textspace=1,cdmethod=1)

# %%
# plot the graph
graph_ranks(avranks_df4, names, cd=cd_df4,width=6, textspace=1,cdmethod=2)
