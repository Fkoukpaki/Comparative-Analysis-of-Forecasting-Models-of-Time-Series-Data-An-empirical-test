# %% [markdown]
# **Statistical tests**

# %% [markdown]
# ***Friedman Test on the outputs of the models***

# %%
# !pip install scikit_posthocs

# %%
# Importing libraries
from scipy import stats
import scikit_posthocs as sp
import numpy as np
import pandas as pd
import math
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.backends.backend_agg import FigureCanvasAgg

# %%
# import the dataset
NHITS = pd.read_csv("/content/drive/MyDrive/df/NHITS.csv",sep=';',index_col=0)

# %%
NHITS
# Out:
#            n1        n2        n3        n4
# H10  0.108178  0.206236  0.209471  0.226134
# H6   0.100724  0.086622  0.116950  0.150277
# H5   0.074170  0.085405  0.110810  0.137583
# H4   0.080768  0.091140  0.108781  0.137510
# H3   0.078164  0.096712  0.093961  0.125276
# H2   0.088254  0.117661  0.123399  0.142913
# H1   0.084429  0.110667  0.089374  0.107245

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(NHITS, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("NHITS")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
ES = pd.read_csv("/content/drive/MyDrive/df/ES.csv",sep=';',index_col=0)
ES
# Out:
#            n1        n2        n3        n4
# H10  0.317520  0.317520  0.317520  0.317520
# H6   0.175894  0.175894  0.175894  0.175894
# H5   0.157304  0.157304  0.157304  0.157304
# H4   0.141641  0.141641  0.141641  0.141641
# H3   0.135016  0.135016  0.135016  0.135016
# H2   0.101632  0.101632  0.101632  0.101634
# H1   0.074761  0.074761  0.074761  0.074762

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(ES, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("ES")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
ARIMA_ = pd.read_csv("/content/drive/MyDrive/df/ARIMA.csv",sep=';',index_col=0)
ARIMA_
# Out:
#            n1        n2        n3        n4
# H10  0.227508  0.227508  0.227508  0.227508
# H6   0.127935  0.127935  0.127935  0.127935
# H5   0.143387  0.143387  0.143387  0.143387
# H4   0.142661  0.142661  0.142661  0.142661
# H3   0.122816  0.122816  0.122816  0.122816
# H2   0.095463  0.095463  0.095463  0.096619
# H1   0.072838  0.072838  0.072838  0.072964

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(ARIMA_, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("ARIMA")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
PressRidge = pd.read_csv("/content/drive/MyDrive/df/PressRidge.csv",sep=';',index_col=0)
PressRidge
# Out:
#            n1        n2        n3        n4
# H10  0.248082  0.220910  0.265543  0.257982
# H6   0.133640  0.131691  0.132005  0.135732
# H5   0.140321  0.138582  0.135633  0.146454
# H4   0.137043  0.123002  0.121874  0.121093
# H3   0.132966  0.123908  0.113240  0.117825
# H2   0.092316  0.090154  0.085754  0.081015
# H1   0.076305  0.080652  0.077853  0.072137

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(PressRidge, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("PressRidge")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
PipeRF = pd.read_csv("/content/drive/MyDrive/df/PipeRF.csv",sep=';',index_col=0)
PipeRF
# Out:
#            n1        n2        n3        n4
# H10  0.431535  0.412436  0.407994  0.297235
# H6   0.343732  0.310795  0.269229  0.292265
# H5   0.202190  0.238969  0.228322  0.235583
# H4   0.217378  0.238943  0.231048  0.223068
# H3   0.231111  0.256432  0.238487  0.255343
# H2   0.239011  0.209599  0.197902  0.217190
# H1   0.262972  0.250105  0.188108  0.189723

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(PipeRF, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("PipeRF")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
PipeKNN = pd.read_csv("/content/drive/MyDrive/df/PipeKNN.csv",sep=';',index_col=0)
PipeKNN
# Out:
#            n1        n2        n3        n4
# H10  0.427661  0.353598  0.250028  0.230624
# H6   0.306021  0.224966  0.224032  0.224801
# H5   0.354548  0.194638  0.175727  0.175727
# H4   0.286604  0.172303  0.172303  0.172715
# H3   0.253630  0.189278  0.194977  0.194134
# H2   0.181273  0.175329  0.173079  0.175617
# H1   0.153302  0.143314  0.143633  0.147304

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(PipeKNN, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("PipeKNN")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
EnetCV = pd.read_csv("/content/drive/MyDrive/df/EnetCV.csv",sep=';',index_col=0)
EnetCV
# Out:
#            n1        n2        n3        n4
# H10  0.248086  0.220906  0.280335  0.269860
# H6   0.133636  0.131680  0.131999  0.124681
# H5   0.140317  0.138574  0.135628  0.137776
# H4   0.137038  0.122999  0.121871  0.114690
# H3   0.132961  0.123906  0.113238  0.114540
# H2   0.092312  0.090161  0.085761  0.081018
# H1   0.076301  0.080662  0.077862  0.072140

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(EnetCV, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("EnetCV")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
GBR = pd.read_csv("/content/drive/MyDrive/df/GBR.csv",sep=';',index_col=0)
GBR
# Out:
#            n1        n2        n3        n4
# H10  0.215237  0.278262  0.260386  0.169870
# H6   0.158009  0.084085  0.102736  0.089819
# H5   0.077362  0.092637  0.085396  0.083745
# H4   0.089509  0.094856  0.102392  0.095403
# H3   0.125446  0.123481  0.108766  0.107844
# H2   0.081595  0.090480  0.091403  0.087740
# H1   0.086686  0.070715  0.078342  0.082400

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(GBR, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("GBR")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
KNN = pd.read_csv("/content/drive/MyDrive/df/KNN.csv",sep=';',index_col=0)
KNN
# Out:
#            n1        n2        n3        n4
# H10  0.130168  0.143774  0.144753  0.128817
# H6   0.113050  0.095827  0.097971  0.078680
# H5   0.083049  0.082222  0.072661  0.077539
# H4   0.125759  0.098641  0.079293  0.076043
# H3   0.108258  0.132437  0.104627  0.086798
# H2   0.108977  0.102373  0.108950  0.092890
# H1   0.091122  0.078425  0.084357  0.083675

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(KNN, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("KNN")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
LassoCV = pd.read_csv("/content/drive/MyDrive/df/LassoCV.csv",sep=';',index_col=0)
LassoCV
# Out:
#            n1        n2        n3        n4
# H10  0.246228  0.232257  0.293223  0.274256
# H6   0.134584  0.143388  0.140157  0.135128
# H5   0.140504  0.145360  0.139908  0.145262
# H4   0.137435  0.121056  0.123706  0.121903
# H3   0.133220  0.120956  0.111034  0.113420
# H2   0.093039  0.084461  0.079883  0.078477
# H1   0.077754  0.074202  0.072404  0.062139

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(LassoCV, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("LassoCV")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
PLS = pd.read_csv("/content/drive/MyDrive/df/PLS.csv",sep=';',index_col=0)
PLS
# Out:
#            n1        n2        n3        n4
# H10  0.249959  0.219483  0.280077  0.271298
# H6   0.181572  0.129357  0.133730  0.128527
# H5   0.194416  0.136167  0.134766  0.145465
# H4   0.193928  0.119787  0.116955  0.111207
# H3   0.176637  0.121845  0.113469  0.110002
# H2   0.117465  0.086780  0.085380  0.078128
# H1   0.091080  0.076491  0.076482  0.073168

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(PLS, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("PLS")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
RF = pd.read_csv("/content/drive/MyDrive/df/RF.csv",sep=';',index_col=0)
RF
# Out:
#            n1        n2        n3        n4
# H10  0.102222  0.093953  0.126928  0.142859
# H6   0.091486  0.077318  0.072405  0.067662
# H5   0.076663  0.068459  0.071319  0.068464
# H4   0.120297  0.089777  0.086402  0.084539
# H3   0.150010  0.113560  0.102996  0.082726
# H2   0.099502  0.093511  0.098336  0.098987
# H1   0.075583  0.070608  0.078695  0.081970

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(RF, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("RF")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
RidgeCV = pd.read_csv("/content/drive/MyDrive/df/RidgeCV.csv",sep=';',index_col=0)
RidgeCV
# Out:
#            n1        n2        n3        n4
# H10  0.248041  0.220949  0.274980  0.258170
# H6   0.133676  0.131789  0.132063  0.135897
# H5   0.140361  0.138652  0.135680  0.146598
# H4   0.137096  0.123028  0.121904  0.118224
# H3   0.133008  0.123923  0.113257  0.114109
# H2   0.092351  0.090099  0.085692  0.080992
# H1   0.076343  0.080565  0.077770  0.072108

# %%
plt.figure(figsize = (20,5))
plt.rcParams.update({'font.size': 12})
sns.heatmap(RidgeCV, cmap = 'coolwarm', vmin = 0, vmax = 1, center=0.20,square= True,annot=True)
plt.title("RidgeCV")
plt.ylabel("different forecasting Horizons H")
plt.show()

# %%
# import the dataset
dfH1 = pd.read_csv("/content/drive/MyDrive/df/dfH1.csv",sep=';')
dfH1
# Out:
#         Models  MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# 0        NHITS    0.197466    0.001938    0.029490    0.088680    0.030232
# 1           ES    0.194425    0.003058    0.117710    0.072066    0.113514
# 2        ARIMA    0.171897    0.003822    0.101212    0.075019    0.106993
# 3   PressRidge    0.142622    0.004261    0.054120    0.051113    0.138950
# 4       PipeRF    0.680299    0.084118    0.202190    0.152951    1.084160
# 5      PipeKNN    0.547560    0.183061    0.178000    0.201625    0.491780
# 6      RidgeCV    0.142377    0.004258    0.054039    0.051025    0.138963
# 7       EnetCV    0.142652    0.004261    0.054129    0.051122    0.138948
# 8      LassoCV    0.112095    0.002241    0.070042    0.057165    0.138113
# 9           RF    0.152380    0.005830    0.044628    0.089394    0.134044
# 10         KNN    0.123836    0.003851    0.056352    0.037581    0.153760
# ...

# %%
NHITS = [0.197466,0.001938,0.029490,0.088680,0.030232,0.008787,0.008701,0.083577,0.095962,0.002361];
ES =	[0.194425,0.003058,0.11771,0.072066,0.113514,0.018965,0.027217,0.007405,0.170632,0.012515];
ARIMA	= [0.171897,0.003822,0.101212,0.075019,0.106993,0.019376,0.019888,0.010649,0.163844,0.015621];
#PressRidge = [0.142622,0.004261,0.054120,0.051113,0.138950,0.016479,0.017214,0.011293,0.135421,0.010597]
#PipeRF = [0.680299,0.084118,0.202190,0.152951,1.084160,0.414204,0.166960,0.036621,0.105180,0.010746]
#PipeKNN = [0.547560,0.183061,0.178000,0.201625,0.491780,0.277512,0.049273,0.020855,0.351336,0.011305]
RidgeCV = [0.142377,	0.004258,	0.054039,	0.051025,	0.138963,	0.016454,	0.017216,	0.011275,	0.135448,	0.010595]
EnetCV =	[0.142652,	0.004261,	0.054129,	0.051122,	0.138948,	0.016482,	0.017214,	0.011295,	0.135418,	0.010598]
LassoCV = [0.112095,	0.002241,	0.070042,	0.057165,	0.138113,	0.013379,	0.016235,	0.008799,	0.144923,	0.011290]
RF	= [0.152380,	0.005830,	0.044628,	0.089394,	0.134044,	0.082395,	0.025177,	0.022116,	0.152085,	0.012962]
KNN	= [0.123836,	0.003851,	0.056352,	0.037581,	0.153760,	0.018195,	0.086483,	0.012971,	0.063157,	0.008430]
GBR	= [0.094186,	0.003832,	0.028577,	0.034520,	0.110402,	0.011705,	0.005453,	0.006898,	0.137141,	0.009292]
PLS	= [0.142652,	0.004261,	0.054129,	0.051122,	0.138948,	0.016482,	0.017214,	0.011295,	0.135418,	0.010598]


plt.boxplot(ARIMA, positions = [1], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(ES, positions = [2], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(RidgeCV, positions = [3], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(LassoCV, positions = [4], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PressRidge, positions = [5], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(PLS, positions = [5], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(EnetCV, positions = [6], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(KNN, positions = [7], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(RF, positions = [8], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PipeKNN, positions = [10], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PipeRF, positions = [11], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(GBR, positions = [9], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(NHITS, positions = [10], widths = 0.9,showmeans= True,meanline=True) ;
plt.gca().xaxis.set_ticklabels(['ARIMA',"ES","RidgeCV","LassoCV","PLS","EnetCV","KNN","RF","GBR","NHITS"]) ;
plt.xticks(rotation=90)
plt.title("MSE_10 splits when model forecasts traffic_counts in 15min")
plt.ylabel("MSE")
plt.axis([0, 11, 0, 1])
plt.show()

# %%
# import the dataset
dfH2 = pd.read_csv("/content/drive/MyDrive/df/dfH2.csv",sep=';')
#dfH2

# %%
NHITS = [0.219206,	0.003868,	0.139220,	0.092719,	0.013497,	0.032754,	0.024070,	0.042035,	0.075168,	0.008990];
ES =	[0.212263,	0.004249,	0.064974,	0.117692,	0.055396,	0.031382,	0.038096,	0.017238,	0.043924,	0.012938];
ARIMA	= [0.164056,	0.004460,	0.045900,	0.119343,	0.055218,	0.027338,	0.024651,	0.011002,	0.048927,	0.019760];
#PressRidge = [0.137907,	0.005583,	0.025529,	0.078510,	0.055778,	0.011414,	0.025076,	0.026203,	0.047705,	0.015774]
#PipeRF = [0.669378,	0.178342,	0.244490,	0.202451,	0.399904,	0.482273,	0.059123,	0.057816,	0.164479,	0.039098]
#PipeKNN = [0.825652,	0.219243,	0.258807,	0.218582,	0.636063,	0.605812,	0.065831,	0.029770,	0.149197,	0.017922]
RidgeCV = [0.137686,	0.005588,	0.025529,	0.078384,	0.055937,	0.011417,	0.025073,	0.026114,	0.047715,	0.015796]
EnetCV =	[0.137934,	0.005583,	0.025529,	0.078525,	0.055761,	0.011414,	0.025077,	0.026213,	0.047703,	0.015772]
LassoCV = [0.110080,	0.003850,	0.024183,	0.078596,	0.073576,	0.011134,	0.023511,	0.015879,	0.055456,	0.020228]
RF	= [0.141478,	0.005876,	0.052988,	0.097123,	0.113176,	0.111014,	0.045356,	0.033386,	0.140646,	0.028918]
KNN	= [0.103236,	0.004201,	0.062705,	0.083603,	0.068874,	0.086465,	0.076027,	0.018872,	0.155752,	0.014492]
GBR	= [0.098779,	0.004076,	0.035227,	0.074561,	0.024003,	0.011688,	0.020983,	0.016390,	0.101754,	0.016742]
PLS	= [0.137934,	0.005554,	0.025529,	0.078525,	0.055761,	0.011414,	0.025077,	0.026213,	0.047703,	0.015772]


plt.boxplot(ARIMA, positions = [1], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(ES, positions = [2], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(RidgeCV, positions = [3], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(LassoCV, positions = [4], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PressRidge, positions = [5], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(PLS, positions = [5], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(EnetCV, positions = [6], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(KNN, positions = [7], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(RF, positions = [8], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PipeKNN, positions = [10], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PipeRF, positions = [11], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(GBR, positions = [9], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(NHITS, positions = [10], widths = 0.9,showmeans= True,meanline=True) ;
plt.gca().xaxis.set_ticklabels(['ARIMA',"ES","RidgeCV","LassoCV","PLS","EnetCV","KNN","RF","GBR","NHITS"]) ;
plt.xticks(rotation=90)
plt.title("MSE_10 splits when model forecasts traffic_counts in 30min")
plt.ylabel("MSE")
plt.axis([0, 11, 0, 1])
plt.show()

# %%
# import the dataset
dfH3 = pd.read_csv("/content/drive/MyDrive/df/dfH3.csv",sep=';')
dfH3
# Out:
#         Models  MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# 0        NHITS    0.163722    0.010810    0.146230    0.094886    0.037945
# 1           ES    0.159948    0.004625    0.168926    0.070305    0.154551
# 2        ARIMA    0.120508    0.007658    0.125962    0.081817    0.104978
# 3   PressRidge    0.102819    0.007795    0.071224    0.097350    0.114095
# 4       PipeRF    0.613625    0.007495    0.163341    0.110784    0.551654
# 5      PipeKNN    0.505739    0.017721    0.184183    0.091297    0.496194
# 6      RidgeCV    0.102639    0.007804    0.071115    0.097375    0.114297
# 7       EnetCV    0.102839    0.007796    0.071236    0.097347    0.114073
# 8      LassoCV    0.082256    0.005907    0.065915    0.101301    0.151156
# 9           RF    0.108525    0.014295    0.066443    0.123263    0.160010
# 10         KNN    0.082250    0.004718    0.081425    0.145291    0.127987
# ...

# %%
NHITS = [0.132580,	0.006061,	0.134033,	0.123047,	0.145265,	0.016765,	0.009539,	0.041925,	0.086942,	0.010403];
ES =	[0.144732,	0.006791,	0.114157,	0.053187,	0.234518,	0.053834,	0.019729,	0.058780,	0.275217,	0.098641];
ARIMA	= [0.111046,	0.013905,	0.101661,	0.068786,	0.242510,	0.067447,	0.007043,	0.067274,	0.279100,	0.166327];
#PressRidge = [0.096582,	0.011165,	0.102291,	0.076496,	0.328074,	0.059154,	0.011088,	0.083549,	0.223637,	0.111436]
#PipeRF = [0.160711,	0.043990,	0.116204,	0.111956,	0.423193,	0.089829,	0.018392,	0.026236,	0.216945,	0.014833]
#PipeKNN = [0.099186,	0.011146,	0.192921,	0.137244,	0.172827,	0.082587,	0.018612,	0.040855,	0.143876,	0.019324]
RidgeCV = [0.096418,	0.011166,	0.102163,	0.076615,	0.328087,	0.059155,	0.011066,	0.083488,	0.223602,	0.111429]
EnetCV =	[0.096599,	0.011168,	0.102305,	0.076482,	0.328074,	0.059153,	0.011090,	0.083556,	0.223640,	0.111437]
LassoCV = [0.079878,	0.008700,	0.084686,	0.094663,	0.351327,	0.053021,	0.007990,	0.084153,	0.216325,	0.115652]
RF	= [0.124299,	0.124126,	0.147317,	0.115345,	0.339789,	0.175200,	0.021719,	0.028282,	0.193641,	0.017553]
KNN	= [0.091348,	0.008285,	0.099368,	0.120222,	0.704350,	0.093045,	0.022149,	0.037101,	0.216794,	0.029837]
GBR	= [0.121875,	0.033051,	0.075784,	0.088355,	0.520792,	0.030244,	0.016967,	0.028364,	0.227733,	0.021572]
PLS	= [0.096599,	0.011173,	0.102305,	0.076482,	0.328754,	0.059153,	0.011090,	0.083556,	0.223640,	0.111437]


plt.boxplot(ARIMA, positions = [1], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(ES, positions = [2], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(RidgeCV, positions = [3], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(LassoCV, positions = [4], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PressRidge, positions = [5], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(PLS, positions = [5], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(EnetCV, positions = [6], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(KNN, positions = [7], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(RF, positions = [8], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PipeKNN, positions = [10], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PipeRF, positions = [11], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(GBR, positions = [9], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(NHITS, positions = [10], widths = 0.9,showmeans= True,meanline=True) ;
plt.gca().xaxis.set_ticklabels(["ARIMA","ES","RidgeCV","LassoCV","PLS","EnetCV","KNN","RF","GBR","NHITS"]) ;
plt.xticks(rotation=90)
plt.title("MSE_10 splits when model forecasts traffic_counts in 60min")
plt.ylabel("MSE")
plt.axis([0, 11, 0, 1])
plt.show()

# %%
# import the dataset
dfH8 = pd.read_csv("/content/drive/MyDrive/df/dfH8.csv",sep=';')
#dfH8

# %%
NHITS = [0.156303,	0.025525,	0.066125,	0.068634,	0.126083,	0.061689,	0.049797,	0.070283,	0.058089,	0.038322];
ES =	[0.133609,	0.061268,	0.485154,	0.139288,	0.474052,	0.203062,	0.027268,	0.101479,	0.173969,	0.680543];
ARIMA	= [0.087212,	0.031808,	0.132639,	0.147787,	0.303665,	0.238408,	0.022549,	0.110144,	0.143813,	0.726349];
#PressRidge = [0.067521,	0.036970,	0.076132,	0.262587,	0.329967,	0.131822,	0.029989,	0.062341,	0.165611,	0.523430]
#PipeRF = [0.201545,	0.111762,	0.485963,	0.112879,	0.439326,	0.138927,	0.014359,	0.072761,	0.557538,	0.112926]
#PipeKNN = [0.090488,	0.058012,	0.092125,	0.115866,	0.327458,	1.027984,	0.012768,	0.107571,	0.574709,	0.420672]
RidgeCV = [0.067415,	0.036876,	0.076050,	0.262215,	0.330017,	0.132090,	0.029986,	0.062212,	0.165844,	0.523450]
EnetCV =	[0.067530,	0.036988,	0.076142,	0.262628,	0.329962,	0.131792,	0.029989,	0.062355,	0.165586,	0.523427]
LassoCV = [0.062864,	0.029008,	0.063768,	0.239716,	0.400831,	0.153284,	0.030421,	0.047674,	0.230068,	0.499965]
RF	= [0.164630,	0.281443,	0.183562,	0.092137,	0.206045,	0.156925,	0.020784,	0.093524,	0.629453,	0.095141]
KNN	= [0.171479,	0.055064,	0.059759,	0.128989,	0.640209,	0.158320,	0.067408,	0.067932,	0.283481,	0.123569]
GBR	= [0.091003,	0.039352,	0.075412,	0.113932,	0.521310,	0.228180,	0.011497,	0.039068,	0.271071,	0.307855]
PLS	= [0.067530,	0.036451,	0.076142,	0.262628,	0.329962,	0.133187,	0.029989,	0.062355,	0.165586,	0.523427]


plt.boxplot(ARIMA, positions = [1], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(ES, positions = [2], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(RidgeCV, positions = [3], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(LassoCV, positions = [4], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PressRidge, positions = [5], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(PLS, positions = [5], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(EnetCV, positions = [6], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(KNN, positions = [7], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(RF, positions = [8], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PipeKNN, positions = [10], widths = 0.9,showmeans= True,meanline=True) ;
#plt.boxplot(PipeRF, positions = [11], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(GBR, positions = [9], widths = 0.9,showmeans= True,meanline=True) ;
plt.boxplot(NHITS, positions = [10], widths = 0.9,showmeans= True,meanline=True) ;
plt.gca().xaxis.set_ticklabels(["ARIMA","ES","RidgeCV","LassoCV","PLS","EnetCV","KNN","RF","GBR","NHITS"]) ;
plt.xticks(rotation=90)
plt.title("MSE_10 splits when model forecasts traffic_counts in 120min")
plt.ylabel("MSE")
plt.axis([0, 11, 0, 1])
plt.show()

# %%
# Setting of the desired alpha/significance level
alpha = 0.05

# %% [markdown]
# **---H = 1**: MSEs obtained by using the 2 most recent historical observations

# %%
# import the dataset
dfH1 = pd.read_csv("/content/drive/MyDrive/df/dfH1.csv",sep=';',index_col=0)
df1= dfH1.iloc[[0,1,2,6,7,8,9,10,11,12]]
df_1=df1.copy()
#df_1
df_1_1= df_1.T
df_1_1
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.197466  0.194425  0.171897  0.142377  0.142652  0.112095
# MSE_split2   0.001938  0.003058  0.003822  0.004258  0.004261  0.002241
# MSE_split3   0.029490  0.117710  0.101212  0.054039  0.054129  0.070042
# MSE_split4   0.088680  0.072066  0.075019  0.051025  0.051122  0.057165
# MSE_split5   0.030232  0.113514  0.106993  0.138963  0.138948  0.138113
# MSE_split6   0.008787  0.018965  0.019376  0.016454  0.016482  0.013379
# MSE_split7   0.008701  0.027217  0.019888  0.017216  0.017214  0.016235
# MSE_split8   0.083577  0.007405  0.010649  0.011275  0.011295  0.008799
# MSE_split9   0.095962  0.170632  0.163844  0.135448  0.135418  0.144923
# MSE_split10  0.002361  0.012515  0.015621  0.010595  0.010598  0.011290
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.152380  0.123836  0.094186  0.142652
# MSE_split2   0.005830  0.003851  0.003832  0.004261
# ...

# %%
dfH1

# %%
#transforming the data

MSE_H1 = np.array(df_1_1)
#MSE_H1
MSE_H1.shape
data_1 = np.asarray(MSE_H1)
num_datasets1, num_methods1 = data_1.shape
print("Methods:", num_methods1, "Datasets:", num_datasets1)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
# statistic of friedman
stat, p= stats.friedmanchisquare(*data_1)
#printing the result
print(stat, p)
# decision rule
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
# Out:
# 80.0509090909091 1.5789335767339668e-13
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True

# %% [markdown]
# Here, the Friedman test statistic is 80.05 and the corresponding p-value is 1.58e-13. As this p-value is less than 0.05, we can reject the null hypothesis which states that the MSEs of the models used are equal whatever the splits. In other words, we have sufficient evidence to conclude that among the models used there are at least two whose MSEs are significantly different. Thus, we performed the Nemenyi test to assess the performance of the models pairwise.

# %% [markdown]
# **2- identify the methods that differ significantly using the Nemenyi test**

# %%
df_1
# Out:
#          MSE_split1  MSE_split2  MSE_split3  MSE_split4  MSE_split5  \
# Models
# NHITS      0.197466    0.001938    0.029490    0.088680    0.030232
# ES         0.194425    0.003058    0.117710    0.072066    0.113514
# ARIMA      0.171897    0.003822    0.101212    0.075019    0.106993
# RidgeCV    0.142377    0.004258    0.054039    0.051025    0.138963
# EnetCV     0.142652    0.004261    0.054129    0.051122    0.138948
# LassoCV    0.112095    0.002241    0.070042    0.057165    0.138113
# RF         0.152380    0.005830    0.044628    0.089394    0.134044
# KNN        0.123836    0.003851    0.056352    0.037581    0.153760
# GBR        0.094186    0.003832    0.028577    0.034520    0.110402
# PLS        0.142652    0.004261    0.054129    0.051122    0.138948
#
#          MSE_split6  MSE_split7  MSE_split8  MSE_split9  MSE_split10
# Models
# NHITS      0.008787    0.008701    0.083577    0.095962     0.002361
# ...

# %%
# average rank of the methods
# tranforming data
df1=df_1
df1['Rank_MSE_split1'] = df1.MSE_split1.rank(ascending = True)
df1['Rank_MSE_split2']=df1.MSE_split2.rank(ascending = True)
df1['Rank_MSE_split3']=df1.MSE_split3.rank(ascending = True)
df1['Rank_MSE_split4'] = df1.MSE_split4.rank(ascending = True)
df1['Rank_MSE_split5']=df1.MSE_split5.rank(ascending = True)
df1['Rank_MSE_split6']=df1.MSE_split6.rank(ascending = True)
df1['Rank_MSE_split7'] = df1.MSE_split7.rank(ascending = True)
df1['Rank_MSE_split8']=df1.MSE_split8.rank(ascending = True)
df1['Rank_MSE_split9']=df1.MSE_split9.rank(ascending = True)
df1['Rank_MSE_split10'] = df1.MSE_split10.rank(ascending = True)
df1.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df1['mean']= df1.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df1['mean']
# Out:
# Models
# NHITS      3.9
# ES         7.0
# ARIMA      7.0
# RidgeCV    5.1
# EnetCV     5.7
# LassoCV    4.7
# RF         7.9
# KNN        5.6
# GBR        2.4
# PLS        5.7
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA','RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df1 = [3.9,7.0,7.0,5.1,5.7,4.7,7.9,5.6,2.4,5.7]

# %%
# defining the critical difference function

def compute_CD(avranks, n, alpha=0.1, test="nemenyi"):
    """
    Returns critical difference for Nemenyi or Bonferroni-Dunn test
    according to given alpha (either alpha="0.05" or alpha="0.1") for average
    ranks and number of tested datasets N. Test can be either "nemenyi" for
    for Nemenyi two tailed test or "bonferroni-dunn" for Bonferroni-Dunn test.
    Args:
	avranks (int or list): list of average ranks or the number of methods
	n (int): number of data sets
	alpha (float): alpha level; must be either 0.05 or 0.1
	test (str): "nemenyi" or "bonferroni-dunn"
    """
    k = avranks if isinstance(avranks, int) else len(avranks)
    d = {("nemenyi", 0.05): [0, 0, 1.959964, 2.343701, 2.569032, 2.727774,
                               2.849705, 2.94832, 3.030879, 3.101730, 3.163684,
                               3.218654, 3.268004, 3.312739, 3.353618, 3.39123,
                               3.426041, 3.458425, 3.488685, 3.517073,
                               3.543799],
         ("nemenyi", 0.1): [0, 0, 1.644854, 2.052293, 2.291341, 2.459516,
                              2.588521, 2.692732, 2.779884, 2.854606, 2.919889,
                              2.977768, 3.029694, 3.076733, 3.119693, 3.159199,
                              3.195743, 3.229723, 3.261461, 3.291224, 3.319233],
         ("bonferroni-dunn", 0.05): [0, 0, 1.960, 2.241, 2.394, 2.498, 2.576,
                                       2.638, 2.690, 2.724, 2.773],
         ("bonferroni-dunn", 0.1): [0, 0, 1.645, 1.960, 2.128, 2.241, 2.326,
                                      2.394, 2.450, 2.498, 2.539]}
    q = d[(test, alpha)]
    cd = q[k] * (k * (k + 1) / (6.0 * n)) ** 0.5
    return cd

# %%
# computing the critical difference

cd_df1=compute_CD(avranks_df1, 10, alpha=0.05, test="bonferroni-dunn")
cd_df1
# Out:
# 3.7546597493425864

# %%
# defining the function to visualise the difference graph

def graph_ranks(avranks, names, cd=None, cdmethod=None, lowv=None, highv=None,
                width=6, textspace=1, reverse=False, filename=None, **kwargs):
    """
    Draws a CD graph, which is used to display  the differences in methods'
    performance. See Janez Demsar, Statistical Comparisons of Classifiers over
    Multiple Data Sets, 7(Jan):1--30, 2006.
    Needs matplotlib to work.
    The image is ploted on `plt` imported using `import matplotlib.pyplot as plt`.
    Args:
        avranks (list of float): average ranks of methods.
        names (list of str): names of methods.
        cd (float): Critical difference used for statistically significance of
            difference between methods.
        cdmethod (int, optional): the method that is compared with other methods
            If omitted, show pairwise comparison of methods
        lowv (int, optional): the lowest shown rank
        highv (int, optional): the highest shown rank
        width (int, optional): default width in inches (default: 6)
        textspace (int, optional): space on figure sides (in inches) for the
            method names (default: 1)
        reverse (bool, optional):  if set to `True`, the lowest rank is on the
            right (default: `False`)
        filename (str, optional): output file name (with extension). If not
            given, the function does not write a file.
    """
    width = float(width)
    textspace = float(textspace)

    def nth(l, n):
        """
        Returns only nth elemnt in a list.
        """
        n = lloc(l, n)
        return [a[n] for a in l]

    def lloc(l, n):
        """
        List location in list of list structure.
        Enable the use of negative locations:
        -1 is the last element, -2 second last...
        """
        if n < 0:
            return len(l[0]) + n
        else:
            return n

    def mxrange(lr):
        """
        Multiple xranges. Can be used to traverse matrices.
        This function is very slow due to unknown number of
        parameters.
        >>> mxrange([3,5])
        [(0, 0), (0, 1), (0, 2), (1, 0), (1, 1), (1, 2)]
        >>> mxrange([[3,5,1],[9,0,-3]])
        [(3, 9), (3, 6), (3, 3), (4, 9), (4, 6), (4, 3)]
        """
        if not len(lr):
            yield ()
        else:
            # it can work with single numbers
            index = lr[0]
            if isinstance(index, int):
                index = [index]
            for a in range(*index):
                for b in mxrange(lr[1:]):
                    yield tuple([a] + list(b))

    def print_figure(fig, *args, **kwargs):
        canvas = FigureCanvasAgg(fig)
        canvas.print_figure(*args, **kwargs)

    sums = avranks

    tempsort = sorted([(a, i) for i, a in enumerate(sums)], reverse=reverse)
    ssums = nth(tempsort, 0)
    sortidx = nth(tempsort, 1)
    nnames = [names[x] for x in sortidx]

    if lowv is None:
        lowv = min(1, int(math.floor(min(ssums))))
    if highv is None:
        highv = max(len(avranks), int(math.ceil(max(ssums))))

    cline = 0.4

    k = len(sums)

    lines = None

    linesblank = 0
    scalewidth = width - 2 * textspace

    def rankpos(rank):
        if not reverse:
            a = rank - lowv
        else:
            a = highv - rank
        return textspace + scalewidth / (highv - lowv) * a

    distanceh = 0.25

    if cd and cdmethod is None:
        # get pairs of non significant methods

        def get_lines(sums, hsd):
            # get all pairs
            lsums = len(sums)
            allpairs = [(i, j) for i, j in mxrange([[lsums], [lsums]]) if j > i]
            # remove not significant
            notSig = [(i, j) for i, j in allpairs
                      if abs(sums[i] - sums[j]) <= hsd]
            # keep only longest

            def no_longer(ij_tuple, notSig):
                i, j = ij_tuple
                for i1, j1 in notSig:
                    if (i1 <= i and j1 > j) or (i1 < i and j1 >= j):
                        return False
                return True

            longest = [(i, j) for i, j in notSig if no_longer((i, j), notSig)]

            return longest

        lines = get_lines(ssums, cd)
        linesblank = 0.2 + 0.2 + (len(lines) - 1) * 0.1

        # add scale
        distanceh = 0.25
        cline += distanceh

    # calculate height needed height of an image
    minnotsignificant = max(2 * 0.2, linesblank)
    height = cline + ((k + 1) / 2) * 0.2 + minnotsignificant

    fig = plt.figure(figsize=(width, height))
    fig.set_facecolor('white')
    ax = fig.add_axes([0, 0, 1, 1])  # reverse y axis
    ax.set_axis_off()

    hf = 1. / height  # height factor
    wf = 1. / width

    def hfl(l):
        return [a * hf for a in l]

    def wfl(l):
        return [a * wf for a in l]


    # Upper left corner is (0,0).
    ax.plot([0, 1], [0, 1], c="w")
    ax.set_xlim(0, 1)
    ax.set_ylim(1, 0)

    def line(l, color='k', **kwargs):
        """
        Input is a list of pairs of points.
        """
        ax.plot(wfl(nth(l, 0)), hfl(nth(l, 1)), color=color, **kwargs)

    def text(x, y, s, *args, **kwargs):
        ax.text(wf * x, hf * y, s, *args, **kwargs)

    line([(textspace, cline), (width - textspace, cline)], linewidth=0.7)

    bigtick = 0.1
    smalltick = 0.05

    tick = None
    for a in list(np.arange(lowv, highv, 0.5)) + [highv]:
        tick = smalltick
        if a == int(a):
            tick = bigtick
        line([(rankpos(a), cline - tick / 2),
              (rankpos(a), cline)],
             linewidth=0.7)

    for a in range(lowv, highv + 1):
        text(rankpos(a), cline - tick / 2 - 0.05, str(a),
             ha="center", va="bottom")

    k = len(ssums)

    for i in range(math.ceil(k / 2)):
        chei = cline + minnotsignificant + i * 0.2
        line([(rankpos(ssums[i]), cline),
              (rankpos(ssums[i]), chei),
              (textspace - 0.1, chei)],
             linewidth=0.7)
        text(textspace - 0.2, chei, nnames[i], ha="right", va="center")

    for i in range(math.ceil(k / 2), k):
        chei = cline + minnotsignificant + (k - i - 1) * 0.2
        line([(rankpos(ssums[i]), cline),
              (rankpos(ssums[i]), chei),
              (textspace + scalewidth + 0.1, chei)],
             linewidth=0.7)
        text(textspace + scalewidth + 0.2, chei, nnames[i],
             ha="left", va="center")

    if cd and cdmethod is None:
        # upper scale
        if not reverse:
            begin, end = rankpos(lowv), rankpos(lowv + cd)
        else:
            begin, end = rankpos(highv), rankpos(highv - cd)

        line([(begin, distanceh), (end, distanceh)], linewidth=0.7)
        line([(begin, distanceh + bigtick / 2),
              (begin, distanceh - bigtick / 2)],
             linewidth=0.7)
        line([(end, distanceh + bigtick / 2),
              (end, distanceh - bigtick / 2)],
             linewidth=0.7)
        text((begin + end) / 2, distanceh - 0.05, "CD",
             ha="center", va="bottom")

        # no-significance lines
        def draw_lines(lines, side=0.05, height=0.1):
            start = cline + 0.2
            for l, r in lines:
                line([(rankpos(ssums[l]) - side, start),
                      (rankpos(ssums[r]) + side, start)],
                     linewidth=2.5)
                start += height

        draw_lines(lines)

    elif cd:
        begin = rankpos(avranks[cdmethod] - cd)
        end = rankpos(avranks[cdmethod] + cd)
        line([(begin, cline), (end, cline)],
             linewidth=2.5)
        line([(begin, cline + bigtick / 2),
              (begin, cline - bigtick / 2)],
             linewidth=2.5)
        line([(end, cline + bigtick / 2),
              (end, cline - bigtick / 2)],
             linewidth=2.5)

    if filename:
        print_figure(fig, filename, **kwargs)

# %%
# plot the graph
graph_ranks(avranks_df1, names, cd=cd_df1,width=6, textspace=1,cdmethod=8)

# %% [markdown]
# **H = 2:** **MSEs obtained by using the 2 most recent historical observations**

# %%
#importing the data
dfH2=pd.read_csv("/content/drive/MyDrive/df/dfH2.csv",sep=';',index_col=0)
df2= dfH2.iloc[[0,1,2,6,7,8,9,10,11,12]]
df_2=df2.copy()
df_2_2= df_2.T
df_2_2
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.219206  0.212263  0.164056  0.137686  0.137934  0.110080
# MSE_split2   0.003868  0.004249  0.004460  0.005588  0.005583  0.003850
# MSE_split3   0.139220  0.064974  0.045900  0.025529  0.025529  0.024183
# MSE_split4   0.092719  0.117692  0.119343  0.078384  0.078525  0.078596
# MSE_split5   0.013497  0.055396  0.055218  0.055937  0.055761  0.073576
# MSE_split6   0.032754  0.031382  0.027338  0.011417  0.011414  0.011134
# MSE_split7   0.024070  0.038096  0.024651  0.025073  0.025077  0.023511
# MSE_split8   0.042035  0.017238  0.011002  0.026114  0.026213  0.015879
# MSE_split9   0.075168  0.043924  0.048927  0.047715  0.047703  0.055456
# MSE_split10  0.008990  0.012938  0.019760  0.015796  0.015772  0.020228
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.141478  0.103236  0.098779  0.137934
# MSE_split2   0.005876  0.004201  0.004076  0.005554
# ...

# %%
# transforming the data
MSE_H2 = np.array(df_2_2)
data_2 = np.asarray(MSE_H2)
num_datasets2, num_methods2 = data_2.shape
print("Methods:", num_methods2, "Datasets:", num_datasets2)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
#statistic of Friedman and decision rule
stat, p = stats.friedmanchisquare(*data_2)
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
print(stat, p)
# Out:
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True
# 72.48000000000002 4.959783396540351e-12

# %% [markdown]
# La statistique du test de Friedman est égale à 72.48 et la p-value correspondante est égale à 4.96e-12. Cette p-value étant inférieure à 0.05, on rejette l'hypothèse nulle qui stipule que les MSEs des prévisions faites par les modèles utilisés sont égaux quel que soit le nombre de splits.En d'autres termes, nous avons suffisamment de preuves pour affirmer qu'il y a au moins deux modèles utilisés qui sont significativement différents au seuil de 5%.

# %%
df_2

# %%
# average rank of the methods
# tranforming data
df2=df_2
df2['Rank_MSE_split1'] = df2.MSE_split1.rank(ascending = True)
df2['Rank_MSE_split2']=df2.MSE_split2.rank(ascending = True)
df2['Rank_MSE_split3']=df2.MSE_split3.rank(ascending = True)
df2['Rank_MSE_split4'] = df2.MSE_split4.rank(ascending = True)
df2['Rank_MSE_split5']=df2.MSE_split5.rank(ascending = True)
df2['Rank_MSE_split6']=df2.MSE_split6.rank(ascending = True)
df2['Rank_MSE_split7'] = df2.MSE_split7.rank(ascending = True)
df2['Rank_MSE_split8']=df2.MSE_split8.rank(ascending = True)
df2['Rank_MSE_split9']=df2.MSE_split9.rank(ascending = True)
df2['Rank_MSE_split10'] = df2.MSE_split10.rank(ascending = True)
df2.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df2['mean']= df2.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df2['mean']
# Out:
# Models
# NHITS      5.9
# ES         5.8
# ARIMA      5.7
# RidgeCV    5.0
# EnetCV     4.9
# LassoCV    3.9
# RF         8.9
# KNN        6.5
# GBR        3.6
# PLS        4.8
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA', 'RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df2 = [5.9,5.8,5.7,5.0,4.9,3.9,8.9,6.5,3.6,4.8]

# %%
# computing the critical difference

cd_df2=compute_CD(avranks_df2, 10, alpha=0.05, test="bonferroni-dunn")
cd_df2
# Out:
# 3.7546597493425864

# %%
# plot the graph
graph_ranks(avranks_df2, names, cd=cd_df2,width=6, textspace=1,cdmethod=8)

# %% [markdown]
# H = 3: NMSEs obtained by using the 2 most recent historical observations

# %%
#reading the data
dfH3= pd.read_csv("/content/drive/MyDrive/df/dfH3.csv",sep=';',index_col=0)
df3= dfH3.iloc[[0,1,2,6,7,8,9,10,11,12]]
df_3=df3.copy()
df_3_3= df_3.T
df_3_3
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.163722  0.159948  0.120508  0.102639  0.102839  0.082256
# MSE_split2   0.010810  0.004625  0.007658  0.007804  0.007796  0.005907
# MSE_split3   0.146230  0.168926  0.125962  0.071115  0.071236  0.065915
# MSE_split4   0.094886  0.070305  0.081817  0.097375  0.097347  0.101301
# MSE_split5   0.037945  0.154551  0.104978  0.114297  0.114073  0.151156
# MSE_split6   0.039700  0.032157  0.040535  0.022988  0.022953  0.023350
# MSE_split7   0.009481  0.017420  0.016226  0.010080  0.010089  0.008990
# MSE_split8   0.050955  0.085999  0.091073  0.072211  0.072221  0.075667
# MSE_split9   0.088795  0.162944  0.153328  0.114824  0.114788  0.127534
# MSE_split10  0.006218  0.014173  0.029136  0.010071  0.010046  0.016436
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.108525  0.082250  0.088874  0.102839
# MSE_split2   0.014295  0.004718  0.008394  0.007772
# ...

# %%
# transforming the data
MSE_H3 = np.array(df_3_3)
data_3= np.asarray(MSE_H3)
num_datasets3, num_methods3 = data_3.shape
print("Methods:", num_methods3, "Datasets:", num_datasets3)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
# statistic of Friedman and decision rule
stat, p = stats.friedmanchisquare(*data_3)
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
print(stat, p)
# Out:
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True
# 74.96727272727276 1.6039855403507479e-12

# %% [markdown]
# La statistique du test de Friedman est égale à 74.97 et la p-value correspondante est égale à 1.60e-12. Cette p-value étant inférieure à 0.05, nous avons rejeté l'hypothèse nulle qui stipule que les MSEs des prévisions faites par les modèles utilisés sont égaux quel que soit le nombre de splits.En d'autres termes, nous avons suffisamment de preuves pour affirmer qu'il y a parmi les modèles utilisés au moins deux dont les MSEs sont significativement différents au seuil de 5%. Ainsi, nous avons réalisé le test de Nemenyi afin de tester les performances des modèles par paires.

# %% [markdown]
# **2- identify the methods that differ significantly using the Nemenyi test**

# %%
# average rank of the methods
# tranforming data
df3=df_3
df3['Rank_MSE_split1'] = df3.MSE_split1.rank(ascending = True)
df3['Rank_MSE_split2']= df3.MSE_split2.rank(ascending = True)
df3['Rank_MSE_split3']= df3.MSE_split3.rank(ascending = True)
df3['Rank_MSE_split4'] = df3.MSE_split4.rank(ascending = True)
df3['Rank_MSE_split5']= df3.MSE_split5.rank(ascending = True)
df3['Rank_MSE_split6']= df3.MSE_split6.rank(ascending = True)
df3['Rank_MSE_split7'] = df3.MSE_split7.rank(ascending = True)
df3['Rank_MSE_split8']= df3.MSE_split8.rank(ascending = True)
df3['Rank_MSE_split9']= df3.MSE_split9.rank(ascending = True)
df3['Rank_MSE_split10'] = df3.MSE_split10.rank(ascending = True)
df3.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df3['mean']= df3.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df3['mean']
# Out:
# Models
# NHITS      4.50
# ES         6.30
# ARIMA      6.30
# RidgeCV    4.60
# EnetCV     4.35
# LassoCV    4.60
# RF         7.50
# KNN        6.60
# GBR        6.00
# PLS        4.25
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA', 'RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df3 = [4.50,6.30,6.30,4.60,4.35,4.60,7.50,6.60,6.00,4.25]

# %%
# computing the critical difference

cd_df3=compute_CD(avranks_df3, 10, alpha=0.05, test="bonferroni-dunn")
cd_df3
# Out:
# 3.7546597493425864

# %%
# plot the graph
graph_ranks(avranks_df3, names, cd=cd_df3,width=6, textspace=1,cdmethod=8)

# %% [markdown]
# H = 4: NMSEs obtained by using the 2 most recent historical observations

# %%
#reading the data
dfH4= pd.read_csv("/content/drive/MyDrive/df/dfH4.csv",sep=';',index_col=0)
df4= dfH4.iloc[[0,1,2,6,7,8,9,10,11,12]]
df_4=df4.copy()
df_4_4= df_4.T
df_4_4
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.132580  0.144732  0.111046  0.096418  0.096599  0.079878
# MSE_split2   0.006061  0.006791  0.013905  0.011166  0.011168  0.008700
# MSE_split3   0.134033  0.114157  0.101661  0.102163  0.102305  0.084686
# MSE_split4   0.123047  0.053187  0.068786  0.076615  0.076482  0.094663
# MSE_split5   0.145265  0.234518  0.242510  0.328087  0.328074  0.351327
# MSE_split6   0.016765  0.053834  0.067447  0.059155  0.059153  0.053021
# MSE_split7   0.009539  0.019729  0.007043  0.011066  0.011090  0.007990
# MSE_split8   0.041925  0.058780  0.067274  0.083488  0.083556  0.084153
# MSE_split9   0.086942  0.275217  0.279100  0.223602  0.223640  0.216325
# MSE_split10  0.010403  0.098641  0.166327  0.111429  0.111437  0.115652
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.124299  0.091348  0.121875  0.096599
# MSE_split2   0.124126  0.008285  0.033051  0.011173
# ...

# %%
# transforming the data
MSE_H4 = np.array(df_4_4)
data_4= np.asarray(MSE_H4)
num_datasets4, num_methods4 = data_4.shape
print("Methods:", num_methods4, "Datasets:", num_datasets4)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
# statistic of Friedman and decision rule
stat, p = stats.friedmanchisquare(*data_4)
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
print(stat, p)
# Out:
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True
# 68.77090909090913 2.6508643689367556e-11

# %% [markdown]
# La statistique du test de Friedman est égale à 68.77 et la p-value correspondante est égale à 2.65e-11 Cette p-value étant inférieure à 0.05, nous allons rejeté l'hypothèse nulle qui stipule que les MSEs des prévisions faites par les modèles utilisés sont égaux quel que soit le nombre de splits.Ainsi, nous pouvons réalisé le test de Nemenyi afin de tester les performances des modèles par paires.

# %% [markdown]
# **2- identify the methods that differ significantly using the Nemenyi test**

# %%
# average rank of the methods
# tranforming data
df4=df_4
df4['Rank_MSE_split1'] = df4.MSE_split1.rank(ascending = True)
df4['Rank_MSE_split2']= df4.MSE_split2.rank(ascending = True)
df4['Rank_MSE_split3']= df4.MSE_split3.rank(ascending = True)
df4['Rank_MSE_split4'] = df4.MSE_split4.rank(ascending = True)
df4['Rank_MSE_split5']= df4.MSE_split5.rank(ascending = True)
df4['Rank_MSE_split6']= df4.MSE_split6.rank(ascending = True)
df4['Rank_MSE_split7'] = df4.MSE_split7.rank(ascending = True)
df4['Rank_MSE_split8']= df4.MSE_split8.rank(ascending = True)
df4['Rank_MSE_split9']= df4.MSE_split9.rank(ascending = True)
df4['Rank_MSE_split10'] = df4.MSE_split10.rank(ascending = True)
df4.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df4['mean']= df4.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df4['mean']
# Out:
# Models
# NHITS      4.0
# ES         5.4
# ARIMA      5.8
# RidgeCV    5.2
# EnetCV     5.8
# LassoCV    4.9
# RF         6.7
# KNN        5.7
# GBR        5.4
# PLS        6.1
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA','RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df4 = [4.0,5.4,5.8,5.2,5.8,4.9,6.7,5.7,5.4,6.1]

# %%
# computing the critical difference

cd_df4=compute_CD(avranks_df4, 10, alpha=0.05, test="bonferroni-dunn")
cd_df4
# Out:
# 3.7546597493425864

# %%
# plot the graph
graph_ranks(avranks_df4, names, cd=cd_df4,width=6, textspace=1,cdmethod=8)

# %% [markdown]
# H = 8: MSEs obtained by using the 2 most recent historical observations

# %%
#reading the data
dfH8= pd.read_csv("/content/drive/MyDrive/df/dfH8.csv",sep=';',index_col=0)
df8= dfH8.iloc[[0,1,2,6,7,8,9,10,11,12]]
df_8=df8.copy()
df_8_8= df_8.T
df_8_8
# Out:
# Models          NHITS        ES     ARIMA   RidgeCV    EnetCV   LassoCV  \
# MSE_split1   0.156303  0.133609  0.087212  0.067415  0.067530  0.062864
# MSE_split2   0.025525  0.061268  0.031808  0.036876  0.036988  0.029008
# MSE_split3   0.066125  0.485154  0.132639  0.076050  0.076142  0.063768
# MSE_split4   0.068634  0.139288  0.147787  0.262215  0.262628  0.239716
# MSE_split5   0.126083  0.474052  0.303665  0.330017  0.329962  0.400831
# MSE_split6   0.061689  0.203062  0.238408  0.132090  0.131792  0.153284
# MSE_split7   0.049797  0.027268  0.022549  0.029986  0.029989  0.030421
# MSE_split8   0.070283  0.101479  0.110144  0.062212  0.062355  0.047674
# MSE_split9   0.058089  0.173969  0.143813  0.165844  0.165586  0.230068
# MSE_split10  0.038322  0.680543  0.726349  0.523450  0.523427  0.499965
#
# Models             RF       KNN       GBR       PLS
# MSE_split1   0.164630  0.171479  0.091003  0.067530
# MSE_split2   0.281443  0.055064  0.039352  0.036451
# ...

# %%
# transforming the data
MSE_H8 = np.array(df_8_8)
data_8= np.asarray(MSE_H8)
num_datasets8, num_methods8 = data_8.shape
print("Methods:", num_methods8, "Datasets:", num_datasets8)
# Out:
# Methods: 10 Datasets: 10

# %% [markdown]
# **1- perform an overall significance test using the Friedman test**

# %%
# statistic of Friedman and decision rule
stat, p = stats.friedmanchisquare(*data_8)
reject = p <= alpha
print("Should we reject H0 (i.e. is there a difference in the means) at the", (1-alpha)*100, "% confidence level?", reject)
print(stat, p)
# Out:
# Should we reject H0 (i.e. is there a difference in the means) at the 95.0 % confidence level? True
# 56.116363636363644 7.457695604935729e-09

# %% [markdown]
# La statistique du test de Friedman est égale à 56.12 et la p-value correspondante est égale à 7.46e-09. Cette p-value étant inférieure à 0.05, nous avons rejeté l'hypothèse nulle qui stipule que les MSEs des prévisions faites par les modèles utilisés sont égaux quel que soit le nombre de splits.En d'autres termes, nous avons suffisamment de preuves pour affirmer qu'il y a parmi les modèles utilisés au moins deux dont les MSEs sont significativement différents. Ainsi, nous avons réalisé le test de Nemenyi afin de tester les performances des modèles par paires.

# %% [markdown]
# **2- identify the methods that differ significantly using the Nemenyi test**

# %%
# average rank of the methods
# tranforming data
df8=df_8
df8['Rank_MSE_split1'] = df8.MSE_split1.rank(ascending = True)
df8['Rank_MSE_split2']= df8.MSE_split2.rank(ascending = True)
df8['Rank_MSE_split3']= df8.MSE_split3.rank(ascending = True)
df8['Rank_MSE_split4'] = df8.MSE_split4.rank(ascending = True)
df8['Rank_MSE_split5']= df8.MSE_split5.rank(ascending = True)
df8['Rank_MSE_split6']= df8.MSE_split6.rank(ascending = True)
df8['Rank_MSE_split7'] = df8.MSE_split7.rank(ascending = True)
df8['Rank_MSE_split8']= df8.MSE_split8.rank(ascending = True)
df8['Rank_MSE_split9']= df8.MSE_split9.rank(ascending = True)
df8['Rank_MSE_split10'] = df8.MSE_split10.rank(ascending = True)
df8.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']]
df8['mean']= df8.loc[:,['Rank_MSE_split1','Rank_MSE_split2','Rank_MSE_split3',
           'Rank_MSE_split4','Rank_MSE_split5','Rank_MSE_split6',
           'Rank_MSE_split7','Rank_MSE_split8','Rank_MSE_split9','Rank_MSE_split10']].T.mean()

# %%
df8['mean']
# Out:
# Models
# NHITS      3.3
# ES         7.5
# ARIMA      6.0
# RidgeCV    5.0
# EnetCV     5.3
# LassoCV    4.6
# RF         6.0
# KNN        6.8
# GBR        5.2
# PLS        5.3
# Name: mean, dtype: float64

# %%
# list of model names and average ranks
names = ['NHITS', 'ES', 'ARIMA', 'RidgeCV','EnetCV','LassoCV','RF','KNN','GBR','PLS']
avranks_df8 = [3.3,7.5,6.0,5.0,5.3,4.6,6.0,6.8,5.2,5.3]

# %%
# computing the critical difference

cd_df8=compute_CD(avranks_df8, 10, alpha=0.05, test="bonferroni-dunn")
cd_df8
# Out:
# 3.7546597493425864

# %%
# plot the graph
graph_ranks(avranks_df8,names, cd=cd_df8,width=6, textspace=1,cdmethod=2)
